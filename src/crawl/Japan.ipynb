# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
'''with open('../../resource/Japan_artist.json') as user_file:
    file_contents = user_file.read()
    parsed_json = set(json.loads(file_contents))
'''
#newList = set()

# %%
def get_all_similar_artist(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        #print(soup)
        similar_artists = soup.select(".big-artist-list-title > a")
        #print(similar_artists)
        for artist in similar_artists:
            if "," in artist or "&" in artist:
                continue
            newList.add(artist.get_text().strip())
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
        
for i in range(101, 478):
    print(i, end=' ')
    get_all_similar_artist(f"https://www.last.fm/tag/japanese/artists?page={i}")
# Out:
# 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305 306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323 324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 340 341 342 343 344 345 346 347 348 349 350 351 352 353 354 355 356 357 358 359 360 361 362 363 364 365 366 367 368 369 370 371 372 373 374 375 376 377 378 379 380 381 382 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 398 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 419 420 421 422 423 424 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474 475 476 477

# %%
len(newList)
# Out:
# 9855

# %%
#newList.update(parsed_json)
newList
# Out:
# {'Azumi',
#  'Tetsuo Kurata',
#  'Crazy:B [天城燐音 (CV:阿座上洋平)、HiMERU (CV:笠間淳)、桜河こはく (CV:海渡翼)、椎名ニキ (CV:山口智広)]',
#  '岩崎元是',
#  '菅野よう子とシートベルツ',
#  '岡咲美保',
#  'Kat McDowell',
#  'hy4_4yh',
#  '北沢強兵',
#  'KODOKULOVE',
#  'Naoki',
#  'Konno Yukari',
#  '植地雅哉',
#  'M・A・O',
#  'ABEX GO GO',
#  'affable noise',
#  'mondialito',
#  'Flying Kids',
#  'Orange Spiny Crab',
#  'Takuya',
#  'Hajime Wakai, Toru Minegishi, Kenta Nagata, Junichi Masuda',
#  'ICE BAHN',
#  '富田美憂',
#  'Rina Satou',
#  '天道花憐(CV.金元寿子)&星ノ守千秋(CV.石見舞菜香)&亜玖璃(CV.大久保瑠美)',
#  'AMPPEZ',
#  '矢澤にこ(CV.徳井青空)',
#  '椎名純平',
#  'Yukio Yamagata',
#  'Mizki',
#  '近江知永',
#  'Joe Rinoie',
#  'Kingons',
#  'Akira Sasaki',
#  '小泉花陽',
#  'YankaNoi',
#  '平山三紀',
#  'Kannagi Rabbits',
#  'やしきん',
#  'Masaki Batoh',
#  'ペドロ & カプリシャス',
#  'Bakufu Slump',
#  'I Think Otherwise',
#  '初音',
#  'KOTOKO TO AKI',
#  'the cold tommy',
#  '高橋徹也',
#  'Tainted Dickmen',
#  'Shiori',
#  '美樹さやか (喜多村英梨) & 佐倉杏子 (野中藍)',
#  'Tsukasa Yatoki',
#  'The Dudoos',
#  'にこりんぱな(矢澤にこ(CV.徳井青空), 星空凛(CV.飯田里穂), 小泉花陽(CV.久保ユリカ))',
#  'Pipo Angels',
#  'Izumi Makura',
#  'discotortion',
#  'DOTAMA×USK',
#  '帆足圭吾・石濱 翔',
#  'Adora Bell',
#  'きくおはな',
#  'Qujila',
#  'ソンソン弁当箱',
#  'ムッシュかまやつ',
#  '平尾昌晃',
#  '福島亜美',
#  'Armelyrics',
#  'じっぷす',
#  'Smorgas',
#  'EXILE TRIBE',
#  'DJWWWW + Nicole Brennan + OROKIN',
#  'Kamui Gakupo, Kaito, Kagamine Len',
#  'Fukusawa Hideyuki',
#  'Icon Feat. R.Cena',
#  'Sadohara Kaori',
#  'Aimer with chelly',
#  '小林泉美 & Flying Mimi Band',
#  'オモイメグラス',
#  'Junichi Masuda & Go Ichinose',
#  'Aya Sueki',
#  'Op',
#  'Midnight Grand Orchestra',
#  'FantasticYouth',
#  '高野寛 + 原田郁子',
#  'カラフィナ(Kalafina)',
#  'ザ・タイガース',
#  'The SUZUKI',
#  'The Hello Works',
#  'LotusJuice',
#  'sheeno mirin',
#  '宇多田ヒカル',
#  'カルテット',
#  'みなを',
#  'さとみ',
#  'Yoshitomi Ryoji, Miyamoto Kyoko',
#  'ムーンライダーズ',
#  'ひろえ純',
#  'ザ・ハッピーズ',
#  '電波少女',
#  'Misty Eyes',
#  '筋肉少女帯',
#  'Hironosuke Satou',
#  'SHIROSE(WHITE JAM)',
#  'MINMI & Nujabes',
#  '太田美知彦',
#  'エイプリルブルー',
#  'Rick Rack',
#  "NON'SHEEP",
#  '24EFFECTS',
#  'TEMPURA KIDZ',
#  'CAPCOM SOUND TEAM Alph Lyla',
#  'るか・ななせ from AIKATSU☆STARS!',
#  'inspire:tion',
#  'Moso Calibration',
#  '由美かおる',
#  'Kuroshitsuji the Musical Cast',
#  'Hassy',
#  '町田直隆',
#  'とんねるず',
#  '末光篤',
#  'SawanoHiroyuki[nZk]',
#  'Dj Yutaka',
#  'Genki Integrated Course in Elementary Japanese',
#  'Fujii Kaze',
#  '島田奈美',
#  '青山陽一',
#  'CLASSIC CHIMES',
#  'Veneo Isrugi',
#  '3470.mon',
#  '宮川弾',
#  'Hommarju vs P*Light',
#  'Roco (CV: Atsuki Nakamura)',
#  '笠松広司',
#  'Maika Leboutet',
#  'AI TAKEKAWA',
#  'Hilcrhyme',
#  'The Pen Friend Club',
#  'Short Story',
#  'SennaRin',
#  '鬼束千寻',
#  'Tsuda Minami',
#  'ツイスト',
#  'EVISBEATS',
#  'DOKONJOFINGER',
#  're:lapse',
#  'Kumi',
#  'Tokiwa',
#  'Bird Bear Hare and Fish',
#  'ビクター・ファンタスティック・オーケストラ',
#  'イモ欽トリオ',
#  '浅香 唯',
#  'Kei Shindou',
#  'Illreme',
#  'Sachie Hiraga',
#  'HIDETAKE TAKAYAMA',
#  'The ChronoHEAD',
#  '津島善子(CV.小林愛香)、国木田花丸(CV.高槻かなこ)、黒澤ルビィ(CV.降幡愛)',
#  'ROOM#NUMBER',
#  'Ｄｅｃａｙ',
#  '吉永小百合',
#  'Toshinori Kondo & IMA',
#  '愛奴',
#  'Salyu',
#  'Valkyrie; 斎宮 宗(CV.高橋広樹)、影片みか(CV.大須賀 純)',
#  '吉田沙織',
#  'ザ・フォーク・クルセダーズ',
#  'カラーボトル',
#  '東方事変',
#  'Tsukihime',
#  'AJISAI',
#  'Nujabes Feat. Uyama Hiroto',
#  'Yasukawa Goro',
#  'NASTY ILL BROTHER S.U.G.I',
#  'Sooda',
#  'Fujisawa Yoshiaki',
#  '上谷麻紀',
#  '毛玉',
#  'Hirofumi Taniguchi',
#  'エイジア エンジニア',
#  '圭',
#  '萬田久子',
#  '回路',
#  'FUJISHOJI ORIGINAL',
#  'Loop Junktion',
#  'Levitatorz',
#  'Junichi Masuda, Go Ichinose, Morikazu Aoki',
#  'Ni-Hao!',
#  '野々原 茜 (CV.小笠原早紀)',
#  '芸能山城組',
#  '高梨康治 / 水谷広実',
#  'SHALLOW WELL',
#  'Akihito Tokunaga',
#  '矢舟テツロー',
#  'Gitaroo Man OST',
#  '浅葱',
#  'Dubsensemania',
#  '北条加蓮',
#  '雨音薫',
#  'ロコ (CV.中村温姫)',
#  'Yukari Hashimoto',
#  'Mieko Shiomi',
#  'Yotaro',
#  'アニメーションズ',
#  '熊木杏里',
#  'ラッツ＆スター',
#  'nyamura',
#  'BREIMEN',
#  'Tom Cat',
#  'ALI PROJECT',
#  'Dear',
#  'metro trip',
#  '(((sssurrounddd)))',
#  'The Inrun Publics',
#  '刀剣男士 team三条',
#  '真里歌',
#  'Koyama Kimiko',
#  'Leo Sato',
#  'Emme',
#  'ちあきなおみ',
#  'Akito Matsuda',
#  'Maiko Okamoto',
#  'Kanako Kondou',
#  'CRAZY VODKA TONIC',
#  '戸越まごめ',
#  'The Spiders',
#  '麹町養蚕館',
#  'Shota Shimizu',
#  'びばるげばる書店',
#  'Bird',
#  'Takuto Kitsuta, Kinta Sato',
#  'ziyoou-vachi',
#  'Flip Flap',
#  'ECD',
#  'yukihiro',
#  'MI8k',
#  '中嶋康二郎',
#  'MAKI+Ma15',
#  '清水嶺',
#  'Chidori',
#  'AOiRO_Manbow',
#  '恋竹林',
#  '高坂桐乃 (竹達彩奈)',
#  'No Lie-Sense',
#  'Only Yesterday',
#  '鶴岡雅義と東京ロマンチカ',
#  'アイドルネッサンス',
#  'シュガー・ベイブ',
#  'Michiru Akiyoshi',
#  'Rosy Roxy Roller',
#  '下田逸郎',
#  '丘みどり',
#  'Hikaru Arata',
#  'Crazy:B; 天城 燐音(CV.阿座上 洋平)、HiMERU(CV.笠間 淳)、桜河 こはく(CV.海渡 翼)、椎名 ニキ(CV.山口 智広)',
#  'FERN PLANET',
#  'saba sister',
#  '椎乃味醂',
#  'Windy Hill',
#  '奇妙礼太郎トラベルスイング楽団',
#  '赤い疑惑',
#  'ヴァリアス・アーティスト',
#  'Knot Impressed & Sam Judah',
#  'Mika Ogawa',
#  'sakurai tomo',
#  'The world will tear us apart',
#  'KENZI MASUBUCHI',
#  'イノトモ',
#  '黛敏郎',
#  '宇波拓、佳村萠と秋山徹次',
#  'Lifetheory',
#  '毛蟹',
#  '中河健・阿知波大輔',
#  'お月さま交響曲',
#  'Various Artists',
#  'Pared',
#  'Anime OST',
#  'Hauta',
#  '田中裕梨',
#  'TANO*C All Stars',
#  '松本梨香',
#  '茅原実里',
#  'TheSpringSummer',
#  'Taizo Takemoto',
#  'ChroNoiR',
#  'Amber’s',
#  'Curly Giraffe',
#  'm-flo loves Chan, Thaitanium, Edison Chen, Ryohei',
#  'メリー・ナイトメア(CV:佐倉綾音)',
#  'Sumika',
#  'Arimachi Masahiko',
#  '川津明日香',
#  'Melody of Oblivion - Senritsu Gekijou he no Izanai',
#  'Radiq Aka Yoshihiro Hanno',
#  '忘れてモーテルズ',
#  'Rinne Yoshida',
#  'Tomoko Fujita',
#  'Eri Ito',
#  'Bank$',
#  'Nona Reeves',
#  'KREVA',
#  'アイドル教室',
#  '2wink/葵 ひなた&葵 ゆうた(CV.斉藤壮馬)',
#  'Lily Chou-Chou',
#  '星歴13夜',
#  'ayumi.',
#  'Stan',
#  'Teruko Akatsuki',
#  'Speed Grapher',
#  '立山秋航',
#  '街角麻婆豆',
#  'Minnnano Kodomochan',
#  'Typhoon24',
#  'Yuya Tegoshi',
#  'あべ静江',
#  'もな from STAR☆ANIS',
#  'QOOLAND',
#  'あじさいタウン',
#  'm2dy',
#  'たつやくんとマユミーヌ',
#  'Oranges & Lemons',
#  'バクバクドキン',
#  "L'eprica",
#  '綿 めぐみ',
#  'Swanky Swipe',
#  'ティン・パン・アレー',
#  'シンドバッド(小野大輔)',
#  '5/4 Takepod',
#  'ドーリィドルチ',
#  'ゴム',
#  'アイスカルフ',
#  "gaze//he's me",
#  'Asako Toki',
#  'Osage',
#  'Zuinosin',
#  'Mao',
#  '立石孝',
#  '雪ノ下雪乃(CV.早見沙織)& 由比ヶ浜結衣(CV.東山奈央)',
#  'Masami Suzuki',
#  'nurié',
#  'DAI DAI DAI',
#  'DJ KOMORI',
#  'Twill',
#  '一木裕樹',
#  'NOGAWA kazune',
#  'SawanoHiroyuki[nZk]:AiNA THE END',
#  'フルカワミキ',
#  'SaToA',
#  'Take ambulance',
#  'その他の短編ズ',
#  'INDIAN-Hi',
#  'Forbear',
#  '100s',
#  '足立賢明',
#  'Anthonello',
#  'Haruki Mino',
#  'Ayumi Hamasaki & Gackt',
#  'Yuzo Kayama',
#  '柊木りお',
#  'Zankyou no Terror',
#  '[unknown]',
#  'YOGURT-pooh',
#  'TAWINGS',
#  'Kagamine Rin/Len feat. Asami Shimoda',
#  'achordion',
#  '椎名豪 featuring 中川奈美',
#  'Hashimoto, Kazumasa',
#  'Eitetsu Hayashi & Kaoru Wada',
#  'Hironobu Inagaki, Atsuyoshi Isemura',
#  '24 -Two Four-',
#  'アトリエ・ボッサ・コンシャス',
#  'DRAMATIC STARS',
#  'a_hisa',
#  'KAI FIVE',
#  'Sawa Angstrom',
#  'TREKKIE TRAX',
#  'Kamenjoshi',
#  'mathru',
#  'Naive Super',
#  'NIAGARA TRIANGLE (山下達郎, 伊藤銀次, 大滝詠一)',
#  '遠藤ゆりか',
#  '黒川沙良',
#  'Keiji Fujiwara',
#  'SUGAR BABE',
#  '鞘師里保',
#  'Oops',
#  '鈴木慶一',
#  'Yukawa Shione',
#  '刀剣男士 formation of 葵咲',
#  'DJ☆GO',
#  'Dessert',
#  'OGRE YOU ASSHOLE',
#  '安藤明子',
#  'PEARL CENTER',
#  '国安わたる',
#  '椎名へきる',
#  'Kujira Yumemi',
#  '辻横由佳',
#  '長門有希（茅原実里）',
#  'POMERANIANS',
#  'Yukopi',
#  '鳴瀬シュウヘイ',
#  'ミソシタ',
#  'スカート',
#  'シャノ',
#  '幼虫社',
#  'オグリキャップ (CV. 高柳知葉)',
#  'Rene Mars',
#  'ゆいこ',
#  '橋本由香利',
#  'あず♪',
#  'ＢＥＮＩ',
#  'ウェザーハーツ',
#  'cinnamons, evening cinema',
#  '週末CITY PLAY BOYZ',
#  'Endou Kenji',
#  '田村ひより(清水香里)',
#  'FictionJunction KEIKO',
#  '鈴木亜美 joins 中田ヤスタカ',
#  'Hatsune Miku & KAITO',
#  'YUIKAORI (Ogura Yui & Ishihara Kaori)',
#  'Frank Luchs',
#  'Heads',
#  '美樹さやか (CV:喜多村英梨)',
#  'ELFENSJóN',
#  'ハイポジ',
#  'SHE IS SUMMER',
#  'The Japan Times',
#  'DeadballP',
#  'Gum Girl',
#  'Yamada Tamaru',
#  '本田未央',
#  '西野カナ feat. WISE',
#  'パール兄弟',
#  'Natsuki Shinomiya (Kishow Taniyama)',
#  'Relax α Wave',
#  '日向めぐみ',
#  '香椎モイミ',
#  'ピンクターボ',
#  'いちご',
#  'GUHROOVY fw. M-Project',
#  '水森亜土',
#  'MOD LUNG',
#  'MW',
#  'ruha',
#  'm-flo loves MONDAY満ちる',
#  'Kazanari Tsubasa (CV: Mizuki Nana)',
#  'Relaxing BGM Project',
#  '村上純',
#  'pupa',
#  'Yuumao',
#  'ÀõÁÖ€ß€Ê‘g',
#  '藤東知夏',
#  'ソ・イングク',
#  'Das Feenreich',
#  'Kepha',
#  'New Strike Zipper',
#  'Youichirou Yoshikawa',
#  '79',
#  '佐々木真里',
#  'TOOBOE',
#  'みつば(高垣彩陽)、ふたば(明坂聡美)、ひとは(戸松遥)',
#  '電気グルーヴ×スチャダラパー',
#  'Misekai',
#  'fraqsea',
#  '梅田サイファー',
#  '全員',
#  'J Soul Brothers',
#  'Sasaki San',
#  '笹井隆司',
#  'Hirano Aya, Chihara Minori, Gotou Yuuko',
#  'Macaroni Empitsu',
#  'Taiji',
#  'GALAXY STANDARD',
#  '敏感少年隊',
#  'BUGVEL',
#  'パイパー',
#  'Reiko Kudo',
#  'Les Romanesques',
#  'Rinaly',
#  'Shanadoo',
#  'Missile Innovation',
#  'ギャルル',
#  '遠野高志',
#  '四ノ宮那月(CV.谷山紀章)',
#  'UNDER17 & Funta',
#  'Tomodachi Life',
#  'Jun Abe',
#  'アニスフィア・ウィン・パレッティア(CV:千本木彩花)',
#  'Kawasumi Ayako & Nakahara Mai & Koshimizu Ami & Kugimiya Rie',
#  'Takanori Iwata',
#  'Steruss',
#  'Yuko Ikoma',
#  'サディスティックス',
#  'chocoxina',
#  'Rampant',
#  'STUNK(CV:JUNJI MAJIMA)',
#  'Goro Kumai',
#  '早見あかり',
#  '二階堂和美',
#  'LUZE',
#  'Rin’',
#  '鈴木 光人',
#  '嶋野百恵',
#  '+α/あるふぁきゅん。',
#  'cro-magnon × Hyouge Mono',
#  '芥川也寸志',
#  'Alchemy+',
#  'HoSoVoSo',
#  'umezu kazutoki KIKI band',
#  '鈴木愛理',
#  '山本精一と不思議ロボット',
#  'Houts',
#  '松岡純也',
#  'Kondou Takashi',
#  '群青の世界',
#  'Kuri Corder Pops Orchestra, Oranges & Lemons',
#  '西田佐知子',
#  'リルネード',
#  '川畑要',
#  'ゆいちゃんず',
#  'Noriko Tadano',
#  'Kairikibear',
#  'シンセカイセン',
#  '田端義夫',
#  'ラーメンズ',
#  'ZIN-SAY!',
#  'Ebz',
#  'Sharon Apple',
#  'uinona',
#  'The Neatbeats',
#  'TVサントラ',
#  'こどもらうんじ',
#  '野宮真貴',
#  'THE CONTINENTAL KIDS',
#  'Nakaido "Chabo" Reichi',
#  '佐藤有香',
#  'Ayane Sakura',
#  'キュアミラクル(CV:高橋李依)',
#  '星井七瀬',
#  'Shin Sakiura',
#  '沢田靖司',
#  '鳴瀬 シュウヘイ',
#  'セレイナ・アン',
#  'クマサン商会',
#  'Shamanic Princess',
#  'キミドリ',
#  'Kazuhiko Sawaguchi',
#  'The Three',
#  '月のテンペスト',
#  'anderlust',
#  'もな from AIKATSU☆STARS!',
#  'Watanabe Yui & Miyake Marie & Arakawa Miho',
#  'Draft King',
#  'Naoki & Tatsh',
#  'Judy',
#  '椿屋四重奏',
#  '田中宏和・鈴木慶一',
#  'Ensemble Nipponia',
#  '山下達郎',
#  'Oedo Sukeroku Taiko',
#  'Cö shu Nie',
#  'Yuto',
#  'Arianne',
#  'ビデオ・サントラ',
#  '鈴木博文',
#  '宮野真守',
#  '沼田出穂',
#  '大槻ケンヂと橘高文彦',
#  'AUN J-CLASSIC ORCHESTRA',
#  'NYANTORA',
#  'Frank Chickens',
#  'IZ*ONE (아이즈원)',
#  'ZOGRAPHOS (Yu_Asahina+Yamajet)',
#  'INUUNIQ',
#  'RAMM ni Haiyoru Nyaruko-san',
#  'めろん畑a go go',
#  'lico',
#  '[lifter]',
#  'TMN',
#  'F&C',
#  'Ru',
#  'Nim',
#  'Ryozo Band',
#  'Kishida Kyoudan & The Akeboshi Rockets',
#  '山本リンダ',
#  'Discord',
#  '西恵利香',
#  'Tetsuji Hayashi',
#  'Haco + Sakamoto Hiromichi',
#  '阿部公弘',
#  '小林未郁',
#  'タテタカコ',
#  'the PeteBest',
#  'DeFame',
#  '絢香×コブクロ',
#  '無力P',
#  '蟲ふるう夜に',
#  'Qyoto',
#  'Monday満ちる',
#  'Azuma',
#  'woltanative',
#  'Keiichi Suzuki & Hirokazu Tanaka',
#  'Momo',
#  'Kiyoshi Maekawa',
#  '神谷浩史＋小野大輔',
#  'ピアノガール',
#  'yeti let you notice',
#  'Michiyo Honda',
#  'DABO, Anarchy & KREVA',
#  'Sharlo & yealina',
#  '高橋李依',
#  'とぴ',
#  'Beautiful Hummingbird',
#  '福島祐子',
#  '高良みゆき(遠藤綾)',
#  'カッパマイナス',
#  '戸川京子',
#  'MOSAIC。WAV',
#  'Takeshi Senoo',
#  'Loveless',
#  'suisoh',
#  'My Eggplant Died Yesterday',
#  'Soul Scream',
#  'Hoon',
#  'Yoshida Hitomi & Hayami Saori',
#  'AM8',
#  '山本はるきち',
#  'Rayons',
#  'Azari & III',
#  '礒部花凜',
#  '塩谷哲',
#  '岡田徹',
#  'Hayashi Shigeki',
#  'yukaD',
#  'Hibari Kyoya',
#  'エクセル・ガールズ',
#  '達見 恵 featured by 佐野宏晃',
#  'DINARY DELTA FORCE',
#  '山崎まさよし',
#  '中村雅俊',
#  '森カリオペ',
#  'Takashi Hirayasu',
#  'End of the World',
#  'SAKAMOTO SHINNOSUKE',
#  'The Japan Ground Self-Defense Force Central Band',
#  'ブタパンチ',
#  'シリカ',
#  '田我流とカイザーソゼ',
#  'Masami Sato',
#  '城田優',
#  'Shurato',
#  'Moines du temple Daitokuji de Kyôto',
#  'Platinum 900',
#  'アカネサス',
#  '田口宏子',
#  'Yukihiro Fukutomi',
#  'Ni Hao!',
#  'Senri Manaka',
#  '伊藤美来',
#  'BABY-CRAYON~1361~',
#  'Group Action',
#  '東大路憲太',
#  'サザンオールスターズ',
#  'The Pullovers',
#  'anNina',
#  'bacho',
#  'Kenji Ootsuki',
#  '小泉花陽(CV.久保ユリカ)',
#  'Sirup',
#  '真島建設社員一同',
#  'Blue Dragon',
#  'Kuri Coder Pops Orchestra',
#  '山本美禰子',
#  '伊吹 翼 (CV.Machico)',
#  '萩原健一',
#  'Joe Hisaishi / Delldongo',
#  '菅田将暉',
#  "シェリル・ノーム starring May'n、ランカ・リー=中島愛",
#  'さっきの女の子、',
#  'Cutting Edge',
#  'e;in',
#  'Ginji Ito',
#  '小出広美',
#  'CINEMA dub MONKS',
#  'はじめにきよし',
#  'Junko Takeuchi',
#  '一ノ宮頼子',
#  'まるりとりゅうが',
#  '新乃ユキヒデ',
#  '横山輝一',
#  'Yae',
#  'DJ ikkodate',
#  'Bivattchee',
#  '里帰り',
#  'Shiraishi',
#  'Yuta Bandoh',
#  'Tiki Tiki Bamboooos',
#  'TU→YU',
#  'Hammer Head Shark',
#  "Jusqu'à Grand-Père",
#  'Kimio Nomura',
#  '桜エビ~ず',
#  'AI-SACHI',
#  'Pikmin',
#  'ryo (supercell) feat.chelly',
#  'みなみけ',
#  '椿',
#  'クレナズム',
#  'RELAX WORLD',
#  '藤澤ノリマサ',
#  'Izumi Kobayashi',
#  '根岸さとり',
#  'カナタジュン',
#  'AZALEA (諏訪ななか, 小宮有紗, 高槻かなこ)',
#  'モノンクル',
#  'Souhei Kano',
#  '焚吐',
#  'PhilHarmoUniQue',
#  'Isoe Toshimichi',
#  'BIG-O & DJ WATARAI',
#  '日渡奈那',
#  'Raji',
#  'オメガトライブ',
#  'Nomi Yuuji',
#  'Hearts Grow',
#  'ガチャガチャダンサーズ',
#  'Sachi & Nao',
#  'かぴたろう',
#  'Cetow',
#  '生田絵梨花',
#  'EOW',
#  'おもしろ三国志',
#  'Kazami',
#  '田中公平 / 浜口史郎',
#  'Naoto Shibata',
#  '渡辺直樹',
#  '米良美一',
#  'Eden; 乱 凪砂(CV.諏訪部順一)、巴 日和(CV.花江夏樹)、七種 茨(CV.逢坂良太)、漣 ジュン(CV.内田雄馬)',
#  'R.H',
#  '辛島美登里',
#  'kitagawa katsutoshi',
#  'Nao☆',
#  'マーガレットズロース',
#  'アルケミスト',
#  'Frances Maya',
#  'ｙｔｒ',
#  'HINOIチーム',
#  'Japan Daisuki',
#  'Kuhakugokko',
#  '緒方智絵里 (大空直美)',
#  '祖堅正慶',
#  'Kobayashi Shuntarou',
#  '阿部義晴',
#  '芳賀敬太',
#  'Takuma Watanabe',
#  '小西香葉·近藤由紀夫(MOKA☆)',
#  '東京中低域',
#  'Azumi Inoue',
#  'Yuko Goto',
#  '藤原さくら',
#  'YANAKIKU',
#  '離婚伝説',
#  'Goro Yamaguchi',
#  'paionia',
#  'Designed People',
#  'Trast',
#  'カチューシャ (cv.金元寿子)',
#  'mamerico',
#  '桑原幸子',
#  'あゆみくりかまき',
#  '瑞葵',
#  'ブラッディ・マンデイ',
#  'ロス',
#  'AozoraFantasii',
#  'ロリィタノイロォゼ',
#  '須藤あきら',
#  'Hirano Aya, Chihara Minori, Gotou Yuuko (Suzumiya Haruhi, Nagato Yuki, Asahina Mikuru)',
#  'school food punishment',
#  'Hi, How Are You?',
#  'ISH-ONE',
#  'Doctrine Doctrine',
#  '布施明',
#  'photograph',
#  'PawPaw',
#  'Monsieur Kamayatsu',
#  'FRUITPOCHETTE',
#  '広川恵一',
#  'アフロマニア',
#  'Nobuyuki Hiyama',
#  '伊藤かずえ',
#  '小原鞠莉(CV.鈴木愛奈)',
#  'Saitama Saishuu Heiki',
#  '若林直美',
#  'KOJI 1200',
#  'Jesus is Dead',
#  'Noriyasu Takeuchi',
#  'Camellia & Nanahira',
#  'Vesuvia Project',
#  'Happy Merry',
#  'Surface',
#  'Natsuko Nisshoku',
#  'Color Filter',
#  'Koji Kondo, Asuka Ota',
#  'Jericho Bunch',
#  '菊池志穂',
#  '井出泰彰',
#  '吉村由美',
#  'CaSSETTE CON-LOS',
#  '→Pia-no-jaC←×葉加瀬太郎',
#  'ちっち',
#  'Ouran Koukou Host Club - Chieco Kawabe',
#  "FAMM'IN",
#  'Ichiro Araki',
#  'Yuuki Ozaki (from Galileo Galilei)',
#  '分島花音',
#  '渥美マリ',
#  'SAY-LA',
#  'Blueberry&Yogurt',
#  '田中秀和',
#  '藍月なくる',
#  'Sakamoto Masayuki',
#  'Tsukimiya Midori',
#  'Kenichiro Suehiro',
#  'minchanbaby',
#  'Maki Mannami',
#  'KANEYORIMASARU',
#  'SawanoHiroyuki[nZk]:mica',
#  'Pochi korone',
#  'Aoki Yutaka',
#  'Tsuki No Wa',
#  'Nenashi',
#  'るか・せな from AIKATSU☆STARS!',
#  '小野麗莎',
#  '坂元輝トリオ',
#  'RUVISH',
#  'CALETWOLF',
#  'Shiraishi Minoru',
#  'Momo Asakura',
#  'Chumei Watanabe',
#  '沖ちづる',
#  'Tommy february⁶',
#  '川村竜',
#  '紅月/蓮巳敬人(CV.梅原裕一郎)、鬼龍紅郎(CV.神尾晋一郎)、神崎颯馬(CV.神永圭佑)',
#  'SINGER SONGER',
#  'Yoshizumi',
#  'Mitchel Matuszak',
#  'Tsuneo Imahori',
#  'your gold, my pink',
#  'Mayumi Fujita, Lotus Juice',
#  'UMEDA CYPHER',
#  '湯浅譲二',
#  '梅林太郎',
#  'FIRE DOG 69',
#  'Tacoyaki Rainbow',
#  'DJ TK',
#  '鈴木茂',
#  '久保あおい',
#  'RabbitJ',
#  'C.C. (ゆかな)',
#  '平野綾, 茅原実里, 後藤邑子',
#  'Ra*bits; 仁兎なずな(CV.米内佑希)、天満光(CV.池田純矢)、真白友也(CV.比留間俊哉)、紫之創(CV.高坂知也)',
#  '蓮実重臣',
#  'Cowboy Bebop OST 3 Blue',
#  'Satou Rina, Inoue Marina & Chihara Minori',
#  '鹿乃',
#  'Levaslater',
#  'SawanoHiroyuki[nZk]:okazakitaiiku',
#  'Water Room',
#  'Zephyr Cradle feat. TAM',
#  '空想委員会',
#  'DATE ME GANE',
#  'ジェル',
#  '燦鳥ノム',
#  'CVLTE',
#  '石川ひとみ',
#  'Genki Book 2',
#  'Zoomgals',
#  'MANT',
#  'butter butter',
#  'Umekichi',
#  'GAGLE x Ovall',
#  '黒百合姉妹',
#  'qadtbep',
#  'wotaku',
#  '輝夜 月',
#  'Rappagariya',
#  '水樹奈々(Nana Mizuki)',
#  '狛枝凪斗(CV.緒方恵美)',
#  'カフカ',
#  '濱田金吾',
#  'trap Black American',
#  '広谷順子',
#  'Opus Inn',
#  '神山純一 J PROJECT',
#  '小棚木もみじ',
#  '山本健司',
#  'Hitomi Kurioshi',
#  'ころん',
#  'サニーデイ・サービス',
#  '朝崎郁恵',
#  '大島はるな',
#  'おとぼけビ〜バ〜',
#  'Arege',
#  'SOLIDEMO',
#  '恩田直幸',
#  '螢',
#  'Igarashi Hiromi',
#  'Yusuke Teranishi',
#  '水原明子',
#  'こだまさおり',
#  '弘妃由実',
#  'Gassyoh',
#  '坂本スミ子',
#  '小池徹平',
#  'LOCAL CONNECT',
#  'Toshihiko Matsunaga',
#  'シユイ',
#  'Oke/a/',
#  '今野宏美',
#  'Sachiko Miyano',
#  'NEW ROMAN TRIO',
#  'Hisaka Yoko',
#  'Omaru Polka',
#  'マーキュロ',
#  '佐々木ゆう子',
#  '原信夫とシャープス・アンド・フラッツ',
#  'DAISHI DANCE×→Pia-no-jaC←',
#  '小山水城',
#  '大和田りつこ',
#  '鈴代紗弓',
#  'ロケットマン',
#  'yardlands',
#  'ザ・ムンズ',
#  "It's",
#  'told',
#  'Judy Ongg',
#  '月詠み',
#  'Furukawa Hiroshi',
#  'Toshiro Masuda, 634Project',
#  'Choro Club',
#  'Kolme',
#  'Wataru Takada',
#  '麻丘めぐみ',
#  'Ａｎｎａｂｅｌ',
#  'Valkyrie [斎宮宗 (CV:高橋広樹)、影片みか (CV:大須賀純)]',
#  'E.D.P.S.',
#  'MooNs(cv.上村祐翔､柿原徹也､森久保祥太郎､大河元気､増田俊樹)',
#  '甲斐智枝美',
#  'The DARARS',
#  'Toru Kitajima',
#  'Trefle',
#  '原由子',
#  'Ryuji Imaichi',
#  '亀岡夏海',
#  'MonyHorse',
#  'highfashionparalyze',
#  'HYPNOSISMIC -D.R.B- (CHU-OH-KU Kotonoha Party)',
#  'Nakajima Dai',
#  'Kotonoha',
#  'Conton Candy',
#  'CARTHIEFSCHOOL',
#  'CIRRRCLE',
#  'KOBAYASHI Yuu',
#  '森山良子',
#  '眞白桃々',
#  '穴井夕子',
#  '清木場俊介 & EXILE ATSUSHI',
#  'she9',
#  'Bubble-B',
#  '如何に崇高な精神といえども、顔面が伴わなければ『彼女』はできない。',
#  'WOODSOFT',
#  'SHUUBI',
#  'The d.e.p',
#  'Kocho',
#  'エミリー スチュアート (CV.郁原ゆう)',
#  '憂病',
#  'Akai Tori',
#  '坂本昌一郎',
#  'Puffyshoes',
#  'Yasuaki Shimizu',
#  'Le Makeup',
#  'Kei',
#  'Halo at yojohan',
#  'Bacon',
#  '坂本美雨',
#  '高橋哲也',
#  'Yonikaii',
#  'Reiji Kawaguchi',
#  'Magdala',
#  'Misae Takamatsu',
#  'Nowlu',
#  'Circus-P',
#  'あんこうチーム',
#  'Gabby & Lopez',
#  'この子',
#  'カルディア',
#  'chocoholic',
#  '市丸',
#  'Abu-Se-Ken',
#  'Ferri',
#  'First Impression',
#  '井上鑑',
#  ...}

# %%
result = filter(lambda artist: ',' not in artist, newList)
result = filter(lambda artist: '&' not in artist, result)
result = list(result)

# %%
len(result)
# Out:
# 9352

# %%
result.sort()
with open("artist_Japan.json", "w") as outfile:
    json.dump(result, outfile)
