# %%
# Chạy cell này đầu tiên
from bs4 import BeautifulSoup
from IPython.display import clear_output
import requests
import json
import os
import pandas as pd

# %%
# Merge file
# Không cần nhạy cell này
'''
from unidecode import unidecode

json_files = {
    "VN": "artist_VietNam.json", 
    "JP": "artist_Japan.json", 
    "EU": "artist_EU.json",
    "USUK": "artist_USUK.json",
    "KR": "artist_Korea.json",
    "Latin": "artist_Latin.json"
}


def normalize_name(name):
    return unidecode(name.lower())

def filter_similar_names(names):
    unique_names = set()
    filtered_names = []
    for name in names:
        normalized_name = normalize_name(name)
        if normalized_name not in unique_names:
            unique_names.add(normalized_name)
            filtered_names.append(name)
    return filtered_names

# Initialize an empty dictionary to store names and areas
name_area_dict = {}

# Loop through each JSON file
for area, json_file in json_files.items():
    with open(f"./{json_file}", 'r') as file:
        names = json.load(file)
        filtered_names = filter_similar_names(names)
        for name in filtered_names:
            if name in name_area_dict:
                name_area_dict[name] += f';{area}'
            else:
                name_area_dict[name] = area

# Convert the dictionary to a DataFrame
df = pd.DataFrame(list(name_area_dict.items()), columns=['Name', 'Area'])

# Save the DataFrame to a CSV file
df.sort_values(by=['Name']).to_csv('artistDataset.csv', index=False)
print("CSV file created successfully.")
'''
''''''
# Out:
# ''

# %%
# Sau đó chạy cell này
def getSongInfo(name, url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        links = soup.select(".play-this-track-playlinks .play-this-track-playlink")
        result = {}
        for link in links:
            result[link.getText().strip()] = link['href']
        return result
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
def crawlAllSongOfArtist(artist):
    try:
        allSongsList = []
        artistQuery = artist.replace("+", "%252B").replace(" ", "+")
        url = f"https://www.last.fm/music/{artistQuery}/+tracks?date_preset=ALL"
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        pages = soup.find_all(attrs={"class": "pagination-page"})
        last_page = int(pages[-1].find('a').get_text().strip()) if len(pages) else 1
        for i in range(1, last_page+1):
        # For test using: 
        #for i in range(1, 2):
            res = requests.get(f"{url}&page={i}")
            res.raise_for_status()
            pg = res.text
            soup = BeautifulSoup(pg, 'html.parser')
            songs = soup.select("tr.chartlist-row > .chartlist-name > a")
            for song in songs:
            # For test using: 
            #for song in songs[:5]:
                songName = song.getText()
                songUrl = song['href']
                allSongsList.append([songName, getSongInfo(songName, f"https://www.last.fm{songUrl}")])
                print(f"artist: {artist} - page: {i}/{last_page} - song: {songName}")
                clear_output(wait=True)
        return allSongsList
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
'''
Bắt đầu từ đây 
1. Đổi lại firstIndex và lastIndex dựa vào danh sách nghệ sĩ được yêu cầu
Minh: 0 - 6320
Ngọc: 6321 - 12640
Quân: 12641 - 18960
Giang: 18961 - 25280
Long: 25280 - 31605
2. Chạy cell này. Giữ internet ổn định và cắm máy đấy rồi đi làm việc khác
Lưu ý: * Sau mỗi nghệ sĩ crawl thành công sẽ lưu vào file. 
Do đó có thể chạy tiếp cell này sau khi stop, tiến trình sẽ tiếp tục.
Tuy nhiên nên hạn chế để tránh lỗi

* Nếu thấy log bên dưới error, lập tức bấm Interrupt và kiểm tra lại internet
'''
####
firstIndex = 8701
lastIndex = 8900
####
target_file_data = None  # Initialize as a list
targetFileName = f'./songData{firstIndex}-{lastIndex}.csv'

# File danh sách nghệ sĩ
artist_df = pd.read_csv('artistDataset.csv')

if os.path.exists(targetFileName):
    target_file_data = pd.read_csv(targetFileName)
else:
    column_names = [
        "title", 
        "artist", 
        "area", 
        "youtube_link", 
        "spotify_link", 
        "release_date", 
        "youtube_view_count", 
        "youtube_like_count", 
        "tag",
        "duration",
        "popularity",
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "loudness",
        "tempo",
    ]
    target_file_data = pd.DataFrame(columns=column_names)
    target_file_data.to_csv(targetFileName, index=False)
    target_file_data = pd.read_csv(targetFileName)

for i in range(firstIndex, lastIndex + 1):
    dfs_to_concat = []
    artist = artist_df.loc[i, "Name"]
    if artist not in target_file_data["artist"].unique():
        for song_info in crawlAllSongOfArtist(artist):
            yt_view_count = None
            yt_like_count = None
            '''
            popularity = None
            duration = None
            danceability = None
            energy = None
            speechiness = None
            acousticness = None
            instrumentalness = None
            liveness = None
            valence = None
            loudness = 0
            tempo = None
            release_date = None
            '''
            if "YouTube" in song_info[1]:
                yt_API_res = requests.get(f'https://api.socialcounts.org/youtube-video-live-view-count/{song_info[1]["YouTube"].split("?v=")[-1]}').json()
                yt_view_count = yt_API_res["est_sub"] if "est_sub" in  yt_API_res else None
                yt_like_count = yt_API_res["table"][0]["count"] if "table" in  yt_API_res else None
            '''
            if "Spotify" in song_info[1]:
                spotify_id = song_info[1]["Spotify"].split("/")[-1]
                spotify_feature_API_res = requests.get(f'https://www.chosic.com/api/tools/audio-features/{spotify_id}')
                spotify_info_API_res = requests.get(f'https://www.chosic.com/api/tools/tracks/{spotify_id}')
                popularity = spotify_info_API_res["popularity"] if "popularity" in spotify_info_API_res else None
                release_date = spotify_info_API_res["album"]["release_date"] if "album" in spotify_info_API_res else None
                duration = spotify_info_API_res["duration_ms"] if "duration_ms" in spotify_info_API_res else None
                danceability = spotify_info_API_res["danceability"] if "danceability" in spotify_info_API_res else None
                energy = spotify_info_API_res["energy"] if "energy" in spotify_info_API_res else None
                speechiness = spotify_info_API_res["speechiness"] if "speechiness" in spotify_info_API_res else None
                acousticness = spotify_info_API_res["acousticness"] if "acousticness" in spotify_info_API_res else None
                instrumentalness = spotify_info_API_res["instrumentalness"] if "instrumentalness" in spotify_info_API_res else None
                liveness = spotify_info_API_res["liveness"] if "liveness" in spotify_info_API_res else None
                valence = spotify_info_API_res["valence"] if "valence" in spotify_info_API_res else None
                loudness = spotify_info_API_res["loudness"] if "loudness" in spotify_info_API_res else None
                tempo = spotify_info_API_res["tempo"] if "tempo" in spotify_info_API_res else None
            '''
            df_to_append = pd.DataFrame({
                "title": [song_info[0]],
                "artist": [artist],
                "area": [artist_df.loc[i, "Area"]],
                "youtube_link": [song_info[1]["YouTube"] if "YouTube" in song_info[1] else None],
                "spotify_link": [song_info[1]["Spotify"] if "Spotify" in song_info[1] else None],
                "youtube_view_count": [yt_view_count],
                "youtube_like_count": [yt_like_count],
                #"duration": [duration],
                #"danceability": [danceability],
                #"energy": [energy],
                #"speechiness": [speechiness],
                #"acousticness": [acousticness],
                #"instrumentalness": [instrumentalness],
                #"liveness": [liveness],
                #"valence": [valence],
                #"loudness": [loudness],
                #"tempo": [tempo],
                "tag": None
            }) 
            dfs_to_concat.append(df_to_append)
        target_file_data = pd.concat([target_file_data] + dfs_to_concat, ignore_index=True)
        target_file_data.to_csv(targetFileName, index=False)
# Out:
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hole/+tracks?date_preset=ALL&page=9 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262E00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holger+Czukay/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6320>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holland/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02D7E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holland+(%ED%99%80%EB%9E%9C%EB%93%9C)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263D30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holland+Baroque/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263010>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hollow+Mellow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2624A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hollywood+Vampires/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E289CABAF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holostars/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C4C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holum+trio/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262C50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Holy+Moses+and+the+High+Rollers/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262DD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HolySmoke/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260E50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Home+Grown/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E289CABA00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Homecomings/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C550>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Homenaje+A+Una+Bella+Cancion/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Homero+y+su+Combo+Con+Pacho+Galan+y+la+Sonora+Curro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263CA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Homma+Yusuke/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2632B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hommarju+feat.+NON/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E289CAA830>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hommarju+feat.+TAKANORI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D49D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hommarju+feat.+mi-mi+%252B+405/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02D750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hommarju+vs+P*Light/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2626E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Homme/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261A20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+Chu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261EA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+Girls/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+J/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D49D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+L+Days/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2617E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+Popcorn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261A80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honey+and+Clover/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HoneyWorks+meets+TrySail/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6320>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honeymoon+Suite/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Eunki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263F10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Gil+Dong+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2633D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Jinyoung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2625C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Joo+Chan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CA60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Ngoc/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D44F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hong+Nhung+Quang+Dung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hongbin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262A70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Honma+Yusuke/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2629E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoobastank/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7490>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoodoo+Gurus/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CA60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoody/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263310>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262950>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HoooW/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hop+Along/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hop+Ca/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6170>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hope+Theory/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262C50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoppo!/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261EA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hopsin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2613F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horace+Brown/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7490>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horacio+'El+Negro'+Hernandez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02F340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horacio+Palencia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horacio+Salinas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262D70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hormonia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E200>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horse+Lords/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D5E10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Horutuna/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261240>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hose/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2612D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoshi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoshi+no+koe/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7A00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoshimachi+Suisei/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02EAD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoshimi+Junna+(CV:+Hinata+Sato)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261A20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoshoi+Soushi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262AD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hosome/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Air+Marketing/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C4C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Boogie+Trio/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D4BB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Chelle+Rae/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2630A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Chip/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Chocolate/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260AC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Eyes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D44F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Hot+Heat/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02F340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Issue/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2633D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Milk/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262E30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Peas+'n+Butter/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262380>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Thumbs+O'Riley/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Tuna/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6170>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hot+Water+Music/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262E00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hotaru/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hotshots/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hotstuffmusic/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7A00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hotter+Than+Teppanyaki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E200>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Houryu+Samejima/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262320>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/House+Nation/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2626E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/House+Rulez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/House+of+Lords/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E290>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Houseside/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D5030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Houshou+Marine/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262BC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Houts/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2625C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hovering+Orville/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263FA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/How+Merry+Marry/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D4E20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Howard+Hewett/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E140>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Howard+Jones/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Howlin+Wolf/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261450>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Howlin'+Wolf/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2630D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoyo+Colorao/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E560>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hoyt+Axton/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B175330>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hozan+Yamamoto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hozier/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0+Minzy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260790>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0i+L%C3%A2m/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B175360>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+B%C3%A1ch/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02D030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Duy%C3%AAn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+H%E1%BA%A3i/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263910>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+L%C3%AA+Vi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Nh%E1%BA%ADt+Minh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CBB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Rapper/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6170>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Th%C3%A0nh+%C4%90%E1%BB%93ng/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2622C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Th%C3%B9y+Linh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262D70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Th%E1%BB%8B+Q%C3%B9ynh+Nhai/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Vi%E1%BB%87t/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28BEB0130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%C3%A0ng+Y%E1%BA%BFn+(Chibi)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C1F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ho%CC%82%CC%80+Ngo%CC%A3c+Ha%CC%80/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2632E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hromadske+radio/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263A90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huancara/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hubert+Porter+and+The+Jamaican+Calypsonians/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C3A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hue/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D4610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huecco/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hues+Corporation/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262BC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hueso+Carrizo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262590>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huey+Dunbar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B48D630>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E920>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugh+Keice/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2625F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+(Con+Danni+%C3%9Abeda)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2629B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Barrancos/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Blanco/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02FEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Blanco+y+su+Conjunto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D6710>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+D+Almonte/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261C30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Fattoruso/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2630A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Henriquez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2621D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Maldoro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B48D570>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Queir%C3%B3s/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CBB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hugo+Racedo+y+su+Conjunto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262E30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huh+Gak/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262950>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hui/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hui+(PENTAGON)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E290>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HuiBand/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D5DE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HujuniseikouyuuP/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261F30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hullabaloo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263910>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humahuaca+Tr%C3%ADo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262C50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humberto+Can%C3%A9/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28BEB0250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humberto+Ram%C3%ADrez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02EAD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humberto+Suarez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2612D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humble+Pie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humming+Bird/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2617B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Humming+Urban+Stereo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02E620>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HumorBeat/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7CD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hun/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hung+Cuong/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263E80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hungry+Days/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260AC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hunter+Hayes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28BEB0130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huong+Giang+Idol/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02D840>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huong+Lan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261D80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huong+Sen+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263AC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huong+Thanh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huong+Thuy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CD00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hupata!/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D4130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hur+Young+Ji/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263B20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huracan+de+Fuego/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hurdy-Gurdy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262DD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hurricane/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28BEB01C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hurt/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CA00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hus/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huwie+Ishizaki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huy+Du/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262950>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huy+Ph%E1%BA%A1m/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02CD90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huy+Vu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D7DF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huy+V%E1%BA%A1c/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HuyR/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261C90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HuynA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huynh+Ai+Vy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B15FF10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Huy%E1%BB%81n+Di%E1%BB%87u+Thu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02DCF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hu%E1%BB%B3nh+T%C3%BA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261B70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hvitmalt+gjerde/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B260640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwa+Sa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262950>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwa+Yo+Bi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02C280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwan+Hee/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D4610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwang+Min+Hyun/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B2621D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwang+Project/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261240>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwang+Woo+Lim/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263C70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwang+Yerin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B15FF10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwangbo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02F640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwanhee+(Fly+To+The+Sky)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B262F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwayobi+Park/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwayobi+%ED%99%94%EC%9A%94%EB%B9%84/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B261870>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hwi+Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28C02F640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HwiSeo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B6D49D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hy0tk/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001E28B263A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# https://api.socialcounts.org/youtube-video-live-view-count/8xg3vE8Ie_E
