# %%
# Chạy cell này đầu tiên
from bs4 import BeautifulSoup
from IPython.display import clear_output
import requests
import json
import os
import pandas as pd

# %%
# Merge file
# Không cần nhạy cell này
'''
from unidecode import unidecode

json_files = {
    "VN": "artist_VietNam.json", 
    "JP": "artist_Japan.json", 
    "EU": "artist_EU.json",
    "USUK": "artist_USUK.json",
    "KR": "artist_Korea.json",
    "Latin": "artist_Latin.json"
}


def normalize_name(name):
    return unidecode(name.lower())

def filter_similar_names(names):
    unique_names = set()
    filtered_names = []
    for name in names:
        normalized_name = normalize_name(name)
        if normalized_name not in unique_names:
            unique_names.add(normalized_name)
            filtered_names.append(name)
    return filtered_names

# Initialize an empty dictionary to store names and areas
name_area_dict = {}

# Loop through each JSON file
for area, json_file in json_files.items():
    with open(f"./{json_file}", 'r') as file:
        names = json.load(file)
        filtered_names = filter_similar_names(names)
        for name in filtered_names:
            if name in name_area_dict:
                name_area_dict[name] += f';{area}'
            else:
                name_area_dict[name] = area

# Convert the dictionary to a DataFrame
df = pd.DataFrame(list(name_area_dict.items()), columns=['Name', 'Area'])

# Save the DataFrame to a CSV file
df.sort_values(by=['Name']).to_csv('artistDataset.csv', index=False)
print("CSV file created successfully.")
'''
''''''
# Out:
# ''

# %%
# Sau đó chạy cell này
def getSongInfo(name, url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        links = soup.select(".play-this-track-playlinks .play-this-track-playlink")
        result = {}
        for link in links:
            result[link.getText().strip()] = link['href']
        return result
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
def crawlAllSongOfArtist(artist):
    try:
        allSongsList = []
        artistQuery = artist.replace("+", "%252B").replace(" ", "+")
        url = f"https://www.last.fm/music/{artistQuery}/+tracks?date_preset=ALL"
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        pages = soup.find_all(attrs={"class": "pagination-page"})
        last_page = int(pages[-1].find('a').get_text().strip()) if len(pages) else 1
        for i in range(1, last_page+1):
        # For test using: 
        #for i in range(1, 2):
            res = requests.get(f"{url}&page={i}")
            res.raise_for_status()
            pg = res.text
            soup = BeautifulSoup(pg, 'html.parser')
            songs = soup.select("tr.chartlist-row > .chartlist-name > a")
            for song in songs:
            # For test using: 
            #for song in songs[:5]:
                songName = song.getText()
                songUrl = song['href']
                allSongsList.append([songName, getSongInfo(songName, f"https://www.last.fm{songUrl}")])
                print(f"artist: {artist} - page: {i}/{last_page} - song: {songName}")
                clear_output(wait=True)
        return allSongsList
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
'''
Bắt đầu từ đây 
1. Đổi lại firstIndex và lastIndex dựa vào danh sách nghệ sĩ được yêu cầu
Minh: 0 - 6320
Ngọc: 6321 - 12640
Quân: 12641 - 18960
Giang: 18961 - 25280
Long: 25280 - 31605
2. Chạy cell này. Giữ internet ổn định và cắm máy đấy rồi đi làm việc khác
Lưu ý: * Sau mỗi nghệ sĩ crawl thành công sẽ lưu vào file. 
Do đó có thể chạy tiếp cell này sau khi stop, tiến trình sẽ tiếp tục.
Tuy nhiên nên hạn chế để tránh lỗi

* Nếu thấy log bên dưới error, lập tức bấm Interrupt và kiểm tra lại internet
'''
####
firstIndex = 9101
lastIndex = 9300
####
target_file_data = None  # Initialize as a list
targetFileName = f'./songData{firstIndex}-{lastIndex}.csv'

# File danh sách nghệ sĩ
artist_df = pd.read_csv('artistDataset.csv')

if os.path.exists(targetFileName):
    target_file_data = pd.read_csv(targetFileName)
else:
    column_names = [
        "title", 
        "artist", 
        "area", 
        "youtube_link", 
        "spotify_link", 
        "release_date", 
        "youtube_view_count", 
        "youtube_like_count", 
        "tag",
        "duration",
        "popularity",
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "loudness",
        "tempo",
    ]
    target_file_data = pd.DataFrame(columns=column_names)
    target_file_data.to_csv(targetFileName, index=False)
    target_file_data = pd.read_csv(targetFileName)

for i in range(firstIndex, lastIndex + 1):
    dfs_to_concat = []
    artist = artist_df.loc[i, "Name"]
    if artist not in target_file_data["artist"].unique():
        for song_info in crawlAllSongOfArtist(artist):
            yt_view_count = None
            yt_like_count = None
            '''
            popularity = None
            duration = None
            danceability = None
            energy = None
            speechiness = None
            acousticness = None
            instrumentalness = None
            liveness = None
            valence = None
            loudness = 0
            tempo = None
            release_date = None
            '''
            if "YouTube" in song_info[1]:
                yt_API_res = requests.get(f'https://api.socialcounts.org/youtube-video-live-view-count/{song_info[1]["YouTube"].split("?v=")[-1]}').json()
                yt_view_count = yt_API_res["est_sub"] if "est_sub" in  yt_API_res else None
                yt_like_count = yt_API_res["table"][0]["count"] if "table" in  yt_API_res else None
            '''
            if "Spotify" in song_info[1]:
                spotify_id = song_info[1]["Spotify"].split("/")[-1]
                spotify_feature_API_res = requests.get(f'https://www.chosic.com/api/tools/audio-features/{spotify_id}')
                spotify_info_API_res = requests.get(f'https://www.chosic.com/api/tools/tracks/{spotify_id}')
                popularity = spotify_info_API_res["popularity"] if "popularity" in spotify_info_API_res else None
                release_date = spotify_info_API_res["album"]["release_date"] if "album" in spotify_info_API_res else None
                duration = spotify_info_API_res["duration_ms"] if "duration_ms" in spotify_info_API_res else None
                danceability = spotify_info_API_res["danceability"] if "danceability" in spotify_info_API_res else None
                energy = spotify_info_API_res["energy"] if "energy" in spotify_info_API_res else None
                speechiness = spotify_info_API_res["speechiness"] if "speechiness" in spotify_info_API_res else None
                acousticness = spotify_info_API_res["acousticness"] if "acousticness" in spotify_info_API_res else None
                instrumentalness = spotify_info_API_res["instrumentalness"] if "instrumentalness" in spotify_info_API_res else None
                liveness = spotify_info_API_res["liveness"] if "liveness" in spotify_info_API_res else None
                valence = spotify_info_API_res["valence"] if "valence" in spotify_info_API_res else None
                loudness = spotify_info_API_res["loudness"] if "loudness" in spotify_info_API_res else None
                tempo = spotify_info_API_res["tempo"] if "tempo" in spotify_info_API_res else None
            '''
            df_to_append = pd.DataFrame({
                "title": [song_info[0]],
                "artist": [artist],
                "area": [artist_df.loc[i, "Area"]],
                "youtube_link": [song_info[1]["YouTube"] if "YouTube" in song_info[1] else None],
                "spotify_link": [song_info[1]["Spotify"] if "Spotify" in song_info[1] else None],
                "youtube_view_count": [yt_view_count],
                "youtube_like_count": [yt_like_count],
                #"duration": [duration],
                #"danceability": [danceability],
                #"energy": [energy],
                #"speechiness": [speechiness],
                #"acousticness": [acousticness],
                #"instrumentalness": [instrumentalness],
                #"liveness": [liveness],
                #"valence": [valence],
                #"loudness": [loudness],
                #"tempo": [tempo],
                "tag": None
            }) 
            dfs_to_concat.append(df_to_append)
        target_file_data = pd.concat([target_file_data] + dfs_to_concat, ignore_index=True)
        target_file_data.to_csv(targetFileName, index=False)
# Out:
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Idlewild/+tracks?date_preset=ALL&page=9 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Idol+College/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76A40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/If+By+Yes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A11390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Igarashi+Hiromi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iggy+Pop/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477ED40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ignacio+Pe%C3%B1a/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A75600>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ignacio+Pineiro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A74DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Igor+Gerzina/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA471CAC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Igor+Levit/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iida+Toshinobu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E500>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ike+Moriz/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E0E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ike+Reiko/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B32E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ike+Yorihiro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46BDE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikezawa+Haruna/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EBF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikimono-Gakari/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikimono-gakari%EF%BC%88%E3%81%84%E3%81%8D%E3%82%82%E3%81%AE%E3%81%8C%E3%81%8B%E3%82%8A%EF%BC%89/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279FD90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikira+Baru/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A10D30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikizukuri/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA471CCD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikka+Shinjyuu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikkitousen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikkitousen+Original+Soundtrack/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D3C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B33A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikue+Asazaki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46BDA80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikuko/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E6B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikuko+Mimori/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477DF30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikuo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418F1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikurru/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A11210>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ikuta+Aiko/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418F190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Il+Balletto+di+Bronzo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477CB20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Il+Divo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477CA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Il+Volo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46BDE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Il+volo+di+Icaro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB8F70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IlKobra/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B35E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ileana+P%C3%A9rez+Vel%C3%A1zquez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilegales/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FFA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilegales+Feat.+Monchy+Y+Alexandra/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA403DF30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E29DB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iljimae+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418EF50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ill+Sugi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F5B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illa+J/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FAF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illapu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279DE10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illcit+Tsuboi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2C80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illmatic+Buddha+Mc's/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279FC10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illnoledge/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illreme/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D9F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illuminine/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4BD5AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Illya+Kuryaki+And+The+Valderramas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A11330>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilona/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4AD7040>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilse+Hendrix/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477CF40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilse+Olivo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D570>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilssa+Gil/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279F190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ilya+Beshevli/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418EFB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Il%C3%AA+Aiy%C3%AA+E+Gilberto+Gil/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B35E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Im+the+Noise/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EF80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ImY/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Image/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D0C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imagination/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A13130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imagine+Dragons/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA27F2890>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imai+Chihiro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E6E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imani+Zubeh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imelda+May/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279FBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imelda+Miller/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418EF50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Immasoul/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F6D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Immature/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Immortal+Technique/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imogen+Heap/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2B190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Impaofsweden/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B3580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imperio+del+Verso/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E29F00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Implakable/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Imprint/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F220>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Improject/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46BDA80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/In+197666/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A11330>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/In+Company+of+Men/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4BD53C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/In+Layers/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/In+The+Heights+Cast/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FA90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ina/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012B929E3C40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inaction/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inai+Keiji/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA568D810>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inca+Sapi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EAA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inca+Taki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F310>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inca+The+Peruvian+Ensemble/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA403DBD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Incendio/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A13BB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Incontrol/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB9030>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Incubus/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F6D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indeep/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C820>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/India/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4C98250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/India+(feat+Juan+Gabriel)+%5BVersion+Salsa%5D/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2BC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/India.Arie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E28340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indica/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477DE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indigo+Girls/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E530>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indigo+Mist/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F6A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indigosthevia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A13A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Indo+Tribe/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2A7A050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Industria+Del+Amor/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ines+Gaviria/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D1B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iness+Mezel/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA27F27A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Infants/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2EF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Infectious+Grooves/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2B6A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Infinite/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FA90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Infinity+of+Sound+(%EC%95%84%EC%9D%B4%EC%97%90%EC%8A%A4)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FA00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingar+Zach+/+Miguel+%C3%81ngel+Tolosa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA403DE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingela+Jansson/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CBA2C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inger+Nielsen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4BD53C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingrid+Andress/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FA00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingrid+Laien/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F310>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingrid+Laubrock+%252B+Andy+Milne/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E28340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingrid+Laubrock+%252B+Kris+Davis/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279E710>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingvar+Lygren/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E28340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ingvild+N%C3%A6ss/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F0A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inhaler/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inidian+Race/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA27F2740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Initial'L/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB8FD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inmanetica/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA27F2740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inner+Life/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D570>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Innuendo+Sax+Quartet/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inori/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2B190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inoue+Kazuhiko/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA279FBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inoue+Marina/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2B190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inri+Ezel/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E800>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Insane+Youth/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inshow+ha/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA451C280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inshow-ha/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA403DE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Insomnia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4C98250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inspectah+Deck/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inspiral+Carpets/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Instant+Funk/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B35E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Instant+Romantic+Floor/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA418F190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Instituto+Mexicano+Del+Sonido/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B33A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Insultanes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ins%C3%B3lito+Universo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F8E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Intelligent+Jazz/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA451C280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Interactivo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A75D80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Intercriminis/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4810B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Interlunium/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/International+Dub+Ambassadors/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E0E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/International+Jet+Set/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B32E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Internet+Bad+Boys/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76C80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Internet+Money/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B3070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Interpol/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477CD90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Intersection/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Interstellar+Genocide/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E890>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inti+Ayras/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76410>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inti+Mujus/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D8D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inti+y+Vicente/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E500>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inti-Lllimani/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EFE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Intro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B36A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Introspective+Sound+Project/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A74F10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Intuit/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B3400>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Invisible/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Invitro+Electro+Rock+Pop/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E110>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iny/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D8D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Inya/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76AD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ioannis+Halikias/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E500>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iodio/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FCD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iommi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ippo+Yamada/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2C80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ir+Sais/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A75D80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irakere/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B36A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irakere+Featuring+Chucho+Valdes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477DAB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irene+Cara/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irene+Farrera/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irepelusa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A75750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iris+Azquinezer/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iris+DeMent/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iris+Porturas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F3A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irlanda+Valenzuela/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B31F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irma+Dorantes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A77730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irma+Thomas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B3400>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irma+Vila/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EEC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irma+Vila+y+Su+Mariachi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irma%CC%83o+Victor/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C820>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iron+Butterfly/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A74F10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iron+Maiden/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477EFE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iron+Savior/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E980>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Irony/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D8D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iruka/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA46B2F50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ir%C3%A9+Oyal%C3%A9+Sextet/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76B60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isa+Mebarak/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2BEB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isa+P/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477DAB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac+(365+Daband)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB8DF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac+Delgado/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A752D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac+Fern%C3%A1ndez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB90C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac+Hayes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477D390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaac+Shepard/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477E9B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabel+Adams/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2A4D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabel+Aldunate/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A74100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabel+III/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2AC80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabel+Madow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabel+Pantoja/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477C0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabela+Merced/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB8C10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabela+Souza/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A76A40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isabela+de+Souza/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4CB8DF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isadora/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaia+Huron/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA477F100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isaiah+Rashad/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA2E2A080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Isamu+Ohira/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000012BA4A75D80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# https://api.socialcounts.org/youtube-video-live-view-count/8xg3vE8Ie_E
