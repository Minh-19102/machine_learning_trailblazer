# %%
# Chạy cell này đầu tiên
from bs4 import BeautifulSoup
from IPython.display import clear_output
import requests
import json
import os
import pandas as pd

# %%
# Merge file
# Không cần nhạy cell này
'''
from unidecode import unidecode

json_files = {
    "VN": "artist_VietNam.json", 
    "JP": "artist_Japan.json", 
    "EU": "artist_EU.json",
    "USUK": "artist_USUK.json",
    "KR": "artist_Korea.json",
    "Latin": "artist_Latin.json"
}


def normalize_name(name):
    return unidecode(name.lower())

def filter_similar_names(names):
    unique_names = set()
    filtered_names = []
    for name in names:
        normalized_name = normalize_name(name)
        if normalized_name not in unique_names:
            unique_names.add(normalized_name)
            filtered_names.append(name)
    return filtered_names

# Initialize an empty dictionary to store names and areas
name_area_dict = {}

# Loop through each JSON file
for area, json_file in json_files.items():
    with open(f"./{json_file}", 'r') as file:
        names = json.load(file)
        filtered_names = filter_similar_names(names)
        for name in filtered_names:
            if name in name_area_dict:
                name_area_dict[name] += f';{area}'
            else:
                name_area_dict[name] = area

# Convert the dictionary to a DataFrame
df = pd.DataFrame(list(name_area_dict.items()), columns=['Name', 'Area'])

# Save the DataFrame to a CSV file
df.sort_values(by=['Name']).to_csv('artistDataset.csv', index=False)
print("CSV file created successfully.")
'''
''''''
# Out:
# ''

# %%
# Sau đó chạy cell này
def getSongInfo(name, url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        links = soup.select(".play-this-track-playlinks .play-this-track-playlink")
        result = {}
        for link in links:
            result[link.getText().strip()] = link['href']
        return result
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
def crawlAllSongOfArtist(artist):
    try:
        allSongsList = []
        artistQuery = artist.replace("+", "%252B").replace(" ", "+")
        url = f"https://www.last.fm/music/{artistQuery}/+tracks?date_preset=ALL"
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        pages = soup.find_all(attrs={"class": "pagination-page"})
        last_page = int(pages[-1].find('a').get_text().strip()) if len(pages) else 1
        for i in range(1, last_page+1):
        # For test using: 
        #for i in range(1, 2):
            res = requests.get(f"{url}&page={i}")
            res.raise_for_status()
            pg = res.text
            soup = BeautifulSoup(pg, 'html.parser')
            songs = soup.select("tr.chartlist-row > .chartlist-name > a")
            for song in songs:
            # For test using: 
            #for song in songs[:5]:
                songName = song.getText()
                songUrl = song['href']
                allSongsList.append([songName, getSongInfo(songName, f"https://www.last.fm{songUrl}")])
                print(f"artist: {artist} - page: {i}/{last_page} - song: {songName}")
                clear_output(wait=True)
        return allSongsList
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
'''
Bắt đầu từ đây 
1. Đổi lại firstIndex và lastIndex dựa vào danh sách nghệ sĩ được yêu cầu
Minh: 0 - 6320
Ngọc: 6321 - 12640
Quân: 12641 - 18960
Giang: 18961 - 25280
Long: 25280 - 31605
2. Chạy cell này. Giữ internet ổn định và cắm máy đấy rồi đi làm việc khác
Lưu ý: * Sau mỗi nghệ sĩ crawl thành công sẽ lưu vào file. 
Do đó có thể chạy tiếp cell này sau khi stop, tiến trình sẽ tiếp tục.
Tuy nhiên nên hạn chế để tránh lỗi

* Nếu thấy log bên dưới error, lập tức bấm Interrupt và kiểm tra lại internet
'''
####
firstIndex = 8301
lastIndex = 8500
####
target_file_data = None  # Initialize as a list
targetFileName = f'./songData{firstIndex}-{lastIndex}.csv'

# File danh sách nghệ sĩ
artist_df = pd.read_csv('artistDataset.csv')

if os.path.exists(targetFileName):
    target_file_data = pd.read_csv(targetFileName)
else:
    column_names = [
        "title", 
        "artist", 
        "area", 
        "youtube_link", 
        "spotify_link", 
        "release_date", 
        "youtube_view_count", 
        "youtube_like_count", 
        "tag",
        "duration",
        "popularity",
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "loudness",
        "tempo",
    ]
    target_file_data = pd.DataFrame(columns=column_names)
    target_file_data.to_csv(targetFileName, index=False)
    target_file_data = pd.read_csv(targetFileName)

for i in range(firstIndex, lastIndex + 1):
    dfs_to_concat = []
    artist = artist_df.loc[i, "Name"]
    if artist not in target_file_data["artist"].unique():
        for song_info in crawlAllSongOfArtist(artist):
            yt_view_count = None
            yt_like_count = None
            '''
            popularity = None
            duration = None
            danceability = None
            energy = None
            speechiness = None
            acousticness = None
            instrumentalness = None
            liveness = None
            valence = None
            loudness = 0
            tempo = None
            release_date = None
            '''
            if "YouTube" in song_info[1]:
                yt_API_res = requests.get(f'https://api.socialcounts.org/youtube-video-live-view-count/{song_info[1]["YouTube"].split("?v=")[-1]}').json()
                yt_view_count = yt_API_res["est_sub"] if "est_sub" in  yt_API_res else None
                yt_like_count = yt_API_res["table"][0]["count"] if "table" in  yt_API_res else None
            '''
            if "Spotify" in song_info[1]:
                spotify_id = song_info[1]["Spotify"].split("/")[-1]
                spotify_feature_API_res = requests.get(f'https://www.chosic.com/api/tools/audio-features/{spotify_id}')
                spotify_info_API_res = requests.get(f'https://www.chosic.com/api/tools/tracks/{spotify_id}')
                popularity = spotify_info_API_res["popularity"] if "popularity" in spotify_info_API_res else None
                release_date = spotify_info_API_res["album"]["release_date"] if "album" in spotify_info_API_res else None
                duration = spotify_info_API_res["duration_ms"] if "duration_ms" in spotify_info_API_res else None
                danceability = spotify_info_API_res["danceability"] if "danceability" in spotify_info_API_res else None
                energy = spotify_info_API_res["energy"] if "energy" in spotify_info_API_res else None
                speechiness = spotify_info_API_res["speechiness"] if "speechiness" in spotify_info_API_res else None
                acousticness = spotify_info_API_res["acousticness"] if "acousticness" in spotify_info_API_res else None
                instrumentalness = spotify_info_API_res["instrumentalness"] if "instrumentalness" in spotify_info_API_res else None
                liveness = spotify_info_API_res["liveness"] if "liveness" in spotify_info_API_res else None
                valence = spotify_info_API_res["valence"] if "valence" in spotify_info_API_res else None
                loudness = spotify_info_API_res["loudness"] if "loudness" in spotify_info_API_res else None
                tempo = spotify_info_API_res["tempo"] if "tempo" in spotify_info_API_res else None
            '''
            df_to_append = pd.DataFrame({
                "title": [song_info[0]],
                "artist": [artist],
                "area": [artist_df.loc[i, "Area"]],
                "youtube_link": [song_info[1]["YouTube"] if "YouTube" in song_info[1] else None],
                "spotify_link": [song_info[1]["Spotify"] if "Spotify" in song_info[1] else None],
                "youtube_view_count": [yt_view_count],
                "youtube_like_count": [yt_like_count],
                #"duration": [duration],
                #"danceability": [danceability],
                #"energy": [energy],
                #"speechiness": [speechiness],
                #"acousticness": [acousticness],
                #"instrumentalness": [instrumentalness],
                #"liveness": [liveness],
                #"valence": [valence],
                #"loudness": [loudness],
                #"tempo": [tempo],
                "tag": None
            }) 
            dfs_to_concat.append(df_to_append)
        target_file_data = pd.concat([target_file_data] + dfs_to_concat, ignore_index=True)
        target_file_data.to_csv(targetFileName, index=False)
# Out:
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hanson/+tracks?date_preset=ALL&page=2 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB353C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hanul/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE920730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hanyuu+Maigo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE921270>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Around!/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Heads+NANIYORI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Kuru+Kuru/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Merry/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34D60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Mondays/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2919F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Pledis/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Rhodes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34790>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+Together+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35840>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happy+the+Man/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB367A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Happyface/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hara/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE292770>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hara+Yumi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35F30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haragan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35BD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harald+Helland/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB344C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harany/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290A00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hard+Luck+Blues+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA9810>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hard-Fi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35DB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hardage+-+(Featuring+Jocelyn+Brown)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36AA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hardcore+Female+Agression+Shit/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36E00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hardcore+HSB/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hardcore+Superstar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2911E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hardline/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB379A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hare-brained+Unity/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB373D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harem+Scarem/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hari/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293C70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hari+Won/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harisu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34F70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harlem+River+Drive/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34B20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harmonicats/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36E00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harmonium/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harold+Flow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290FA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harold+Lloyd/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35210>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harpo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35300>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harpy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harry+Belafonte/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harry+Chapin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA8160>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harry+Nilsson/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB372E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harry+Styles/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haru+Kitamura/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruhi+Suzumiya/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE3735E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harukatomiyuki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE291DB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruki+Mino/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35E70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruki+Yamada/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36C20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harukichi+Yamamoto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruko+Komiya/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293430>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruko+Oishi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEAAB00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruko+Tajima/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35F30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruma+Miura/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35DB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harumi+Fuuki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36FE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harumi+MIYAKO/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE372F80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruna+Yokota/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2903D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruno/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB353C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haruy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harvey+Averne/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290EE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harvey+Averne+Barrio+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA9F90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harvey+Danger/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harvey+Weinstein/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35660>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Harveys/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB366E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasegawa+Tomoki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370DF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasenpfeffer+Twat/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293700>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hashiguchikanaderiya+hugs+The+Super+Ball/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB354E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hashtag/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB375B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasil+Adkins/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasso+Gakudan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2925F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hassy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEAAFE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasta+Siempre/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB369B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hasumi+Shigeomi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hate+Feeling/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37490>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hate+Honey/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370FD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hatekjoekkn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290B50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hatfield+and+the+North/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36D40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hattie+Craven/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36C20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hattori+Katsuhisa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB358A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hattori+Takayuki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2919F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haus-A-Holics/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hauschka/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hauser/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hauta/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB346D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Havana+Cafe/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE372590>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Havana+Exotica/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE291450>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Havana+Mood/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Havana+Vibes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34FD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hawk+Arps+Jazz+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB358A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hawkins/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2937C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hawkwind/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haww/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayami+Saori/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB349D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayao+Miyazaki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB361D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayao+Miyazaki+animation+orgel+arrange/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373490>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayashi+Shigeki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290550>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayd%C3%A9e+Milan%C3%A9s/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35BA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayeon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36FE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayley+Kiyoko/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB358A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayley+Westenra/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290A00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hayley+Williams/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA9420>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Haylie+Thai/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hazard+Clique/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hazell+Dean/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34E50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hazuki+Erino/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hazy+Sour+Cherry/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2911E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hazze/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB371C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Head+East/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35D20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Head+Phones+President/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB358A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heading+to+the+Ground/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2938E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Headphone-Tokyo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA81C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heads/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35840>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heads+South/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34850>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Healing+Leaf/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35150>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hear/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hearn+-+Plato+Guitar+Duo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE292830>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heart/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35E70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heart+And+Mind/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heart2Heart/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB345E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HeartB/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE292770>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hearth/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA8160>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heartless+Bastards/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36F20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heartphones/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35EA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hearts+Grow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34E50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heartsdales/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370DF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heartwork/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290B20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heat+Guy+J/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heather+Headley/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36620>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heather+Nova/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB345E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heatmiser/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293CD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heatwave/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEAAB00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heaven+17/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37220>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heaven's+Edge/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB374F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heaven11/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37550>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HeavensDust/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE372F80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heavenstamp/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heavy+Merge/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB342E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hechizeros+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Del+Curto/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+El+Bambino/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290FA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+El+Father/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA9F90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Guerra/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB373D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Lavoe+y+Tito+Puente/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB367A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Lavoe+y+Willie+Colon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36AA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Murrieta/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE372380>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Rey/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2933A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Tricoche/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36020>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+Valentin+y+su+Grupo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36D40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hector+y+Tito+Feat+Don+Omar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hedley/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE291DB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hee+Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEAAFE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HeeJin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35D20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HeeKyung+Na/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36B60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heera/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heinrich+Von+Ofterdingen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE373220>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heiwana+Shizukeza/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293700>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heize/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heize+feat.+Han+Soo+Ji/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB364A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hekel+Tavares/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hela+San/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293A60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helda+Tellez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helen+Jane+Long/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35A80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helen+Ochoa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35420>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helen+Reddy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35480>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helen+Shapiro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE372170>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helen+Sj%C3%B6holm/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2912D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helena+B%C3%B9i+Lan+H%C6%B0%C6%A1ng/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36E30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helena+Drive+5/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helena+Jessie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB356F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heleno/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2933A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helia+Casanovas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEABFD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helio+Matheus/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB354E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helix/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB37DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hell+Girl/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB370A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hellborg+Lane+Selvaganesh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE3718A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hello+Ga-Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2902E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hello+House/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35C00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hello+Stupid+People/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hello+Venus+(%ED%97%AC%EB%A1%9C%EB%B9%84%EB%84%88%EC%8A%A4)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36A40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helloween/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE2919F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hellsing/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDEA9F90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helmet/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34D90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helmy's+Hot+Club/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34850>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Helstar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB34E50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Heltah+Skeltah/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE371480>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hel%C3%A9ne+Lundstr%C3%B6m/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE290A00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36290>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henning+Mankell/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henri+Guedon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35300>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henriette+Ege/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE293430>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henriette+Kristiansen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE4A2380>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henrique+Lazo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB353C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB343D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry+Chuc+va+Dalena/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB35B40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry+Cow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCE370730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry+Lau/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCDC45CF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry+Licett/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB36EC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Henry+Mendez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023FCEB367A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# https://api.socialcounts.org/youtube-video-live-view-count/8xg3vE8Ie_E
