# %%
# Chạy cell này đầu tiên
from bs4 import BeautifulSoup
from IPython.display import clear_output
import requests
import json
import os
import pandas as pd

# %%
# Merge file
# Không cần nhạy cell này
'''
from unidecode import unidecode

json_files = {
    "VN": "artist_VietNam.json", 
    "JP": "artist_Japan.json", 
    "EU": "artist_EU.json",
    "USUK": "artist_USUK.json",
    "KR": "artist_Korea.json",
    "Latin": "artist_Latin.json"
}


def normalize_name(name):
    return unidecode(name.lower())

def filter_similar_names(names):
    unique_names = set()
    filtered_names = []
    for name in names:
        normalized_name = normalize_name(name)
        if normalized_name not in unique_names:
            unique_names.add(normalized_name)
            filtered_names.append(name)
    return filtered_names

# Initialize an empty dictionary to store names and areas
name_area_dict = {}

# Loop through each JSON file
for area, json_file in json_files.items():
    with open(f"./{json_file}", 'r') as file:
        names = json.load(file)
        filtered_names = filter_similar_names(names)
        for name in filtered_names:
            if name in name_area_dict:
                name_area_dict[name] += f';{area}'
            else:
                name_area_dict[name] = area

# Convert the dictionary to a DataFrame
df = pd.DataFrame(list(name_area_dict.items()), columns=['Name', 'Area'])

# Save the DataFrame to a CSV file
df.sort_values(by=['Name']).to_csv('artistDataset.csv', index=False)
print("CSV file created successfully.")
'''
''''''
# Out:
# ''

# %%
# Sau đó chạy cell này
def getSongInfo(name, url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        links = soup.select(".play-this-track-playlinks .play-this-track-playlink")
        result = {}
        for link in links:
            result[link.getText().strip()] = link['href']
        return result
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
def crawlAllSongOfArtist(artist):
    try:
        allSongsList = []
        artistQuery = artist.replace("+", "%252B").replace(" ", "+")
        url = f"https://www.last.fm/music/{artistQuery}/+tracks?date_preset=ALL"
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        pages = soup.find_all(attrs={"class": "pagination-page"})
        last_page = int(pages[-1].find('a').get_text().strip()) if len(pages) else 1
        for i in range(1, last_page+1):
        # For test using: 
        #for i in range(1, 2):
            res = requests.get(f"{url}&page={i}")
            res.raise_for_status()
            pg = res.text
            soup = BeautifulSoup(pg, 'html.parser')
            songs = soup.select("tr.chartlist-row > .chartlist-name > a")
            for song in songs:
            # For test using: 
            #for song in songs[:5]:
                songName = song.getText()
                songUrl = song['href']
                allSongsList.append([songName, getSongInfo(songName, f"https://www.last.fm{songUrl}")])
                print(f"artist: {artist} - page: {i}/{last_page} - song: {songName}")
                clear_output(wait=True)
        return allSongsList
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
'''
Bắt đầu từ đây 
1. Đổi lại firstIndex và lastIndex dựa vào danh sách nghệ sĩ được yêu cầu
Minh: 0 - 6320
Ngọc: 6321 - 12640
Quân: 12641 - 18960
Giang: 18961 - 25280
Long: 25280 - 31605
2. Chạy cell này. Giữ internet ổn định và cắm máy đấy rồi đi làm việc khác
Lưu ý: * Sau mỗi nghệ sĩ crawl thành công sẽ lưu vào file. 
Do đó có thể chạy tiếp cell này sau khi stop, tiến trình sẽ tiếp tục.
Tuy nhiên nên hạn chế để tránh lỗi

* Nếu thấy log bên dưới error, lập tức bấm Interrupt và kiểm tra lại internet
'''
####
firstIndex = 8901
lastIndex = 9100
####
target_file_data = None  # Initialize as a list
targetFileName = f'./songData{firstIndex}-{lastIndex}.csv'

# File danh sách nghệ sĩ
artist_df = pd.read_csv('artistDataset.csv')

if os.path.exists(targetFileName):
    target_file_data = pd.read_csv(targetFileName)
else:
    column_names = [
        "title", 
        "artist", 
        "area", 
        "youtube_link", 
        "spotify_link", 
        "release_date", 
        "youtube_view_count", 
        "youtube_like_count", 
        "tag",
        "duration",
        "popularity",
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "loudness",
        "tempo",
    ]
    target_file_data = pd.DataFrame(columns=column_names)
    target_file_data.to_csv(targetFileName, index=False)
    target_file_data = pd.read_csv(targetFileName)

for i in range(firstIndex, lastIndex + 1):
    dfs_to_concat = []
    artist = artist_df.loc[i, "Name"]
    if artist not in target_file_data["artist"].unique():
        for song_info in crawlAllSongOfArtist(artist):
            yt_view_count = None
            yt_like_count = None
            '''
            popularity = None
            duration = None
            danceability = None
            energy = None
            speechiness = None
            acousticness = None
            instrumentalness = None
            liveness = None
            valence = None
            loudness = 0
            tempo = None
            release_date = None
            '''
            if "YouTube" in song_info[1]:
                yt_API_res = requests.get(f'https://api.socialcounts.org/youtube-video-live-view-count/{song_info[1]["YouTube"].split("?v=")[-1]}').json()
                yt_view_count = yt_API_res["est_sub"] if "est_sub" in  yt_API_res else None
                yt_like_count = yt_API_res["table"][0]["count"] if "table" in  yt_API_res else None
            '''
            if "Spotify" in song_info[1]:
                spotify_id = song_info[1]["Spotify"].split("/")[-1]
                spotify_feature_API_res = requests.get(f'https://www.chosic.com/api/tools/audio-features/{spotify_id}')
                spotify_info_API_res = requests.get(f'https://www.chosic.com/api/tools/tracks/{spotify_id}')
                popularity = spotify_info_API_res["popularity"] if "popularity" in spotify_info_API_res else None
                release_date = spotify_info_API_res["album"]["release_date"] if "album" in spotify_info_API_res else None
                duration = spotify_info_API_res["duration_ms"] if "duration_ms" in spotify_info_API_res else None
                danceability = spotify_info_API_res["danceability"] if "danceability" in spotify_info_API_res else None
                energy = spotify_info_API_res["energy"] if "energy" in spotify_info_API_res else None
                speechiness = spotify_info_API_res["speechiness"] if "speechiness" in spotify_info_API_res else None
                acousticness = spotify_info_API_res["acousticness"] if "acousticness" in spotify_info_API_res else None
                instrumentalness = spotify_info_API_res["instrumentalness"] if "instrumentalness" in spotify_info_API_res else None
                liveness = spotify_info_API_res["liveness"] if "liveness" in spotify_info_API_res else None
                valence = spotify_info_API_res["valence"] if "valence" in spotify_info_API_res else None
                loudness = spotify_info_API_res["loudness"] if "loudness" in spotify_info_API_res else None
                tempo = spotify_info_API_res["tempo"] if "tempo" in spotify_info_API_res else None
            '''
            df_to_append = pd.DataFrame({
                "title": [song_info[0]],
                "artist": [artist],
                "area": [artist_df.loc[i, "Area"]],
                "youtube_link": [song_info[1]["YouTube"] if "YouTube" in song_info[1] else None],
                "spotify_link": [song_info[1]["Spotify"] if "Spotify" in song_info[1] else None],
                "youtube_view_count": [yt_view_count],
                "youtube_like_count": [yt_like_count],
                #"duration": [duration],
                #"danceability": [danceability],
                #"energy": [energy],
                #"speechiness": [speechiness],
                #"acousticness": [acousticness],
                #"instrumentalness": [instrumentalness],
                #"liveness": [liveness],
                #"valence": [valence],
                #"loudness": [loudness],
                #"tempo": [tempo],
                "tag": None
            }) 
            dfs_to_concat.append(df_to_append)
        target_file_data = pd.concat([target_file_data] + dfs_to_concat, ignore_index=True)
        target_file_data.to_csv(targetFileName, index=False)
# Out:
# Request error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HybRefine/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D8D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hydrant+House+Purport+Rife+On+Sleepy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D287C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hydrofobia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28FA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hydrogene/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AEF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyein/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyejin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C400>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyeju/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28F70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyena+(%ED%98%9C%EB%82%98)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyeon+Yeong/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FC10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HyeongseopXEuiwoong/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724B806A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyerin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D7271D1090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyesung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyojung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28F10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyolyn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7B010>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyomin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DC60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyori+Lee+%5B%EC%9D%B4%ED%9A%A8%EB%A6%AC%5D/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D960>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyorin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28A90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyosung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyoyeon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DA80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hypnof%C3%B3n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AD70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hysteric+Blue/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28B50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyuji/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyuk/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28E80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyun+Ah+(4minute)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AE90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyun+Jin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F4C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyun+Jin+Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28730>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyun+Shin+Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D294E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyun+Young/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HyunA+Knowles/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F970>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HyunA(%ED%98%84%EC%95%84)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AF50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyuna+Parker/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D291E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyuna+ft+Jun+Hyung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D286A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyung+Don/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28E80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyungwon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AD70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyunjae/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D9F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Hyunjun+Hur/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28C70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/HzEdge(crystal+P)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28910>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A0+Anh+Tu%E1%BA%A5n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28610>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A0+L%C3%AA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E860>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A0+My/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AE90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A0+Ph%C6%B0%C6%A1ng/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28FD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A0+Thanh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A1t+V%C3%B5i+Qu%C3%AA+H%C3%BA%C3%B3ng/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D290F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A5lfan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AF20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9ctor+%22El+Father%22/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9ctor+Acosta+%22El+Torito%22/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29180>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9ctor+Buitrago/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9ctor+Lavoe/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29450>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9ctor+Rojo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DD20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9l%C3%A8ne/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726200A90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9l%C3%A8ne+Grimaud/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D295D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9l%C3%A8ne+S%C3%A9gara/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28B80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%A9roe+Nacional/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29270>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%B2a+Mi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7AF20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%B2a+T.+Tr%E1%BA%A7n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%B2a+T%E1%BA%A5u/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%B4ng+Nhung/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C3%B9ng+L%C3%A2n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C6%B0%C6%A1ng+Giang/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FA30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C6%B0%C6%A1ng+Ly/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726203BE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C6%B0%C6%A1ng+Th%C6%A1/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D293C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C6%B0%C6%A1ng+Tr%C3%A0m/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28FD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%C6%B0%C6%A1ng+%C4%90%C3%AAm+Bay+Xa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29120>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BA%A1c+San/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726E7ACB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BA%A3i+Nguy%C3%AAn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DD20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93+B%C3%ADch+Ng%E1%BB%8Dc/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29180>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93+L%E1%BB%87+Thu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28E80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93+Quang+Hi%E1%BA%BFu/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93+Qu%E1%BB%B3nh+H%C6%B0%C6%A1ng/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7EC80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93ng+H%E1%BA%A1nh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726203EE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%93ng+V%C3%A2n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D281F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%A3p+ca+Asia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28D00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%E1%BB%A9a+Kim+Tuy%E1%BB%81n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29510>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/H%ED%8B%B0%EB%8B%88/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D6C0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Am+Kloot/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DBD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+DONT+KNOW+HOW+BUT+THEY+FOUND+ME/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Dolci+Signori/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D288E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Don't+Like+Mondays./+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28DC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Gitanos/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Hate+Kate/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726202B60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Love+You!+Project/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28460>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Maniaci+Dei+Dischi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28C10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Shot+Alice/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D286A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+The+Tenderness/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D6C040>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Think+Otherwise/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DCF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+Want/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28220>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+an+I/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+the+Tri+top's/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29BD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I+to+U+$CREAMing!!/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DDB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I'VE+Sound/%E4%BA%95%E5%86%85%E8%88%9E%E5%AD%90/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D7262030A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I'll+(%EC%95%84%EC%9D%BC)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29B10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I'm+Sorry+I+Love+You+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28CA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I's/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28D60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I've/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E800>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I've+Sound/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7EC80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I-ITZY/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I-REN/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D287F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I-RabBits/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29AB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.+Ferrer+-+E.+Ochoa+-+C.+Segundo+-+Ry+Cooder/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D9F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.B.I/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D7262038B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.C.E/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28E80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.M/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29960>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.M+YONI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29300>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.N/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DDB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I.O.I/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F3D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/I/O/I/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29B70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IAmChino/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28160>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IBI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29360>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ICE+BAHN/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DED0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ICHILLIN'/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D7262039D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ICHILLIN'+(%EC%95%84%EC%9D%B4%EC%B9%A0%EB%A6%B0)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28430>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ICU/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D29720>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IDOLiSH7/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D726D28670>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/III/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7EC80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IISO/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D0F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IKB/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CE80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ILE/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D7B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ILL-FAME/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C8E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ILSE/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C280>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ILY:1/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ILuv/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F010>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IM/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E500>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IMALU/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E440>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IMERUAT/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E5C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IMFACT/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C6D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IMLAY/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D570>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IMPERIAL+CIRCUS/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IN2IT/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F820>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INDIAN-Hi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INDOW/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INFINITE+F/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E920>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INFINITE+H/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBFBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INKT/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DC60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INTER+GiRLS/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E290>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INTO1/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C070>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INTO1+RIKIMARU/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INTO1+SANTA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBC5E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INUUNIQ/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INXS/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E5C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/INZARGI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E1A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IOAH/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IOSYS+feat.+3L/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF430>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IOSYS+feat.+NJK+Record/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F700>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IPT/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IQ/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IRIS+%EC%95%84%EC%9D%B4%EB%A6%AC%EC%8A%A4/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F5B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IRON+ATTACK!+feat.+ABSOLUTE+AREA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IRRIS/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CE50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ISAK+N+JIYEON/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ISH-ONE/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ISSA+x+Soulja/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F700>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ISSEI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBC5E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ISTA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F5B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ITM/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/ITZY/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IU/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CE50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IU+with+Seulong/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF2E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IU+%EC%95%84%EC%9D%B4%EC%9C%A0/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IVE/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IZ/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IZ*ONE/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F5B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IZ*ONE+(%EC%95%84%EC%9D%B4%EC%A6%88%EC%9B%90)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBFC70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IZ4648/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F010>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/IZA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D960>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iago+Fern%C3%A1ndez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F520>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ian+Anderson/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F8E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ian+Brown/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF1C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ian+Gillan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D900>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ian+Hunter/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E470>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ian+Munsick/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CF40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iannis+Xenakis/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7D1E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ibadi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724DBF250>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ibrahim+Ferrer/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CD90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ibrahim+Ferrer+Con+Los+Bocucos/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E3E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ibrahim+Ferrer+con+Chepin+y+su+Orquesta+Oriental/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icarus+Dawn/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F310>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ice+Cube/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E2C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ice-T/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iced+Earth/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7EF50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icehouse/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DBD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iceman/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F220>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Iceon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FB20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichiban+Kasuga(Kazuhiro+Nakaya)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7CEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichigo+Ichie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7EB00>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichiko+Aoba/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DE70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichikoro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DB40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichimaru/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F7F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichiro+Araki/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FFA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichiro+Nitta/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ichiyanagi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C460>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ici+Anvers/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7FC10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C790>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icon+Feat.+R.Cena/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E1A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icon+feat.+CAMRY/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7F940>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Icon+feat.+MAKI/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7C9D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ida+Maria/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7E3B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Idde+Schultz/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D724F7DF60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# https://api.socialcounts.org/youtube-video-live-view-count/8xg3vE8Ie_E
