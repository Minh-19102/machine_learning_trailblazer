# %%
# Chạy cell này đầu tiên
from bs4 import BeautifulSoup
from IPython.display import clear_output
import requests
import json
import os
import pandas as pd

# %%
# Merge file
# Không cần nhạy cell này
'''
from unidecode import unidecode

json_files = {
    "VN": "artist_VietNam.json", 
    "JP": "artist_Japan.json", 
    "EU": "artist_EU.json",
    "USUK": "artist_USUK.json",
    "KR": "artist_Korea.json",
    "Latin": "artist_Latin.json"
}


def normalize_name(name):
    return unidecode(name.lower())

def filter_similar_names(names):
    unique_names = set()
    filtered_names = []
    for name in names:
        normalized_name = normalize_name(name)
        if normalized_name not in unique_names:
            unique_names.add(normalized_name)
            filtered_names.append(name)
    return filtered_names

# Initialize an empty dictionary to store names and areas
name_area_dict = {}

# Loop through each JSON file
for area, json_file in json_files.items():
    with open(f"./{json_file}", 'r') as file:
        names = json.load(file)
        filtered_names = filter_similar_names(names)
        for name in filtered_names:
            if name in name_area_dict:
                name_area_dict[name] += f';{area}'
            else:
                name_area_dict[name] = area

# Convert the dictionary to a DataFrame
df = pd.DataFrame(list(name_area_dict.items()), columns=['Name', 'Area'])

# Save the DataFrame to a CSV file
df.sort_values(by=['Name']).to_csv('artistDataset.csv', index=False)
print("CSV file created successfully.")
'''
''''''
# Out:
# ''

# %%
# Sau đó chạy cell này
def getSongInfo(name, url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        links = soup.select(".play-this-track-playlinks .play-this-track-playlink")
        result = {}
        for link in links:
            result[link.getText().strip()] = link['href']
        return result
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return {}
    except Exception as e:
        print(f"An error occurred: {e}")
        return {}
def crawlAllSongOfArtist(artist):
    try:
        allSongsList = []
        artistQuery = artist.replace("+", "%252B").replace(" ", "+")
        url = f"https://www.last.fm/music/{artistQuery}/+tracks?date_preset=ALL"
        response = requests.get(url)
        response.raise_for_status()
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
        pages = soup.find_all(attrs={"class": "pagination-page"})
        last_page = int(pages[-1].find('a').get_text().strip()) if len(pages) else 1
        for i in range(1, last_page+1):
        # For test using: 
        #for i in range(1, 2):
            res = requests.get(f"{url}&page={i}")
            res.raise_for_status()
            pg = res.text
            soup = BeautifulSoup(pg, 'html.parser')
            songs = soup.select("tr.chartlist-row > .chartlist-name > a")
            for song in songs:
            # For test using: 
            #for song in songs[:5]:
                songName = song.getText()
                songUrl = song['href']
                allSongsList.append([songName, getSongInfo(songName, f"https://www.last.fm{songUrl}")])
                print(f"artist: {artist} - page: {i}/{last_page} - song: {songName}")
                clear_output(wait=True)
        return allSongsList
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
'''
Bắt đầu từ đây 
1. Đổi lại firstIndex và lastIndex dựa vào danh sách nghệ sĩ được yêu cầu
Minh: 0 - 6320
Ngọc: 6321 - 12640
Quân: 12641 - 18960
Giang: 18961 - 25280
Long: 25280 - 31605
2. Chạy cell này. Giữ internet ổn định và cắm máy đấy rồi đi làm việc khác
Lưu ý: * Sau mỗi nghệ sĩ crawl thành công sẽ lưu vào file. 
Do đó có thể chạy tiếp cell này sau khi stop, tiến trình sẽ tiếp tục.
Tuy nhiên nên hạn chế để tránh lỗi

* Nếu thấy log bên dưới error, lập tức bấm Interrupt và kiểm tra lại internet
'''
####
firstIndex = 7501
lastIndex = 7700
####
target_file_data = None  # Initialize as a list
targetFileName = f'./songData{firstIndex}-{lastIndex}.csv'

# File danh sách nghệ sĩ
artist_df = pd.read_csv('artistDataset.csv')

if os.path.exists(targetFileName):
    target_file_data = pd.read_csv(targetFileName)
else:
    column_names = [
        "title", 
        "artist", 
        "area", 
        "youtube_link", 
        "spotify_link", 
        "release_date", 
        "youtube_view_count", 
        "youtube_like_count", 
        "tag",
        "duration",
        "popularity",
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "liveness",
        "valence",
        "loudness",
        "tempo",
    ]
    target_file_data = pd.DataFrame(columns=column_names)
    target_file_data.to_csv(targetFileName, index=False)
    target_file_data = pd.read_csv(targetFileName)

for i in range(firstIndex, lastIndex + 1):
    dfs_to_concat = []
    artist = artist_df.loc[i, "Name"]
    if artist not in target_file_data["artist"].unique():
        for song_info in crawlAllSongOfArtist(artist):
            yt_view_count = None
            yt_like_count = None
            '''
            popularity = None
            duration = None
            danceability = None
            energy = None
            speechiness = None
            acousticness = None
            instrumentalness = None
            liveness = None
            valence = None
            loudness = 0
            tempo = None
            release_date = None
            '''
            if "YouTube" in song_info[1]:
                yt_API_res = requests.get(f'https://api.socialcounts.org/youtube-video-live-view-count/{song_info[1]["YouTube"].split("?v=")[-1]}').json()
                yt_view_count = yt_API_res["est_sub"] if "est_sub" in  yt_API_res else None
                yt_like_count = yt_API_res["table"][0]["count"] if "table" in  yt_API_res else None
            '''
            if "Spotify" in song_info[1]:
                spotify_id = song_info[1]["Spotify"].split("/")[-1]
                spotify_feature_API_res = requests.get(f'https://www.chosic.com/api/tools/audio-features/{spotify_id}')
                spotify_info_API_res = requests.get(f'https://www.chosic.com/api/tools/tracks/{spotify_id}')
                popularity = spotify_info_API_res["popularity"] if "popularity" in spotify_info_API_res else None
                release_date = spotify_info_API_res["album"]["release_date"] if "album" in spotify_info_API_res else None
                duration = spotify_info_API_res["duration_ms"] if "duration_ms" in spotify_info_API_res else None
                danceability = spotify_info_API_res["danceability"] if "danceability" in spotify_info_API_res else None
                energy = spotify_info_API_res["energy"] if "energy" in spotify_info_API_res else None
                speechiness = spotify_info_API_res["speechiness"] if "speechiness" in spotify_info_API_res else None
                acousticness = spotify_info_API_res["acousticness"] if "acousticness" in spotify_info_API_res else None
                instrumentalness = spotify_info_API_res["instrumentalness"] if "instrumentalness" in spotify_info_API_res else None
                liveness = spotify_info_API_res["liveness"] if "liveness" in spotify_info_API_res else None
                valence = spotify_info_API_res["valence"] if "valence" in spotify_info_API_res else None
                loudness = spotify_info_API_res["loudness"] if "loudness" in spotify_info_API_res else None
                tempo = spotify_info_API_res["tempo"] if "tempo" in spotify_info_API_res else None
            '''
            df_to_append = pd.DataFrame({
                "title": [song_info[0]],
                "artist": [artist],
                "area": [artist_df.loc[i, "Area"]],
                "youtube_link": [song_info[1]["YouTube"] if "YouTube" in song_info[1] else None],
                "spotify_link": [song_info[1]["Spotify"] if "Spotify" in song_info[1] else None],
                "youtube_view_count": [yt_view_count],
                "youtube_like_count": [yt_like_count],
                #"duration": [duration],
                #"danceability": [danceability],
                #"energy": [energy],
                #"speechiness": [speechiness],
                #"acousticness": [acousticness],
                #"instrumentalness": [instrumentalness],
                #"liveness": [liveness],
                #"valence": [valence],
                #"loudness": [loudness],
                #"tempo": [tempo],
                "tag": None
            }) 
            dfs_to_concat.append(df_to_append)
        target_file_data = pd.concat([target_file_data] + dfs_to_concat, ignore_index=True)
        target_file_data.to_csv(targetFileName, index=False)
# Out:
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Generations/+tracks?date_preset=ALL&page=3 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B45920E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genesis/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422E9E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genevieve+Marentette/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422F0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genic/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422F2E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genie/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B3A21B40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genitallica/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B45163B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genki+Book+2/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CB20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genki+Integrated+Course+in+Elementary+Japanese/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422C550>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genki+Rockets/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422F0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genki+Sudo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B422F100>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Genneo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46553F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gentaro+Satomura/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EE30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gentle+Giant/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E110>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Geodezik/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E230>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Benson/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EFE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Browne/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4514640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Davidson/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Ezra/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Guzman/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C970>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Harrison/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EBF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Kamikawa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655540>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+McCrae/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C0A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Michael/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F4F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+O'Brien+Ph.D/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E9B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Strait/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Thorogood/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4515E10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+Winston/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D6F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/George+and+the+Good+Vibes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F2E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/GeorgeFranco/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DAB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Georgel/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FFD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Georges+Bizet/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46556C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Georgia+Aguirre/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C040>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Georgia+Webster/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F7C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Georgie+Fame/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C970>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerald/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerald+Levert/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4515960>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerard+Cox/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerardo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D630>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerardo+Matos+Rodriguez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E4A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerardo+Nu%C3%A3%C2%B1ez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D780>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerardo+Ortiz/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4B91E10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gera%C3%A7%C3%A3o+das+Garotas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D2D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerda+Harman/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EE90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerhard+Lehndorff/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D990>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Geri+Halliwell/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F580>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/German+Casas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516140>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/German+Lizarraga+Y+Su+Banda+Estrellas+De+Sinaloa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E320>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Germ%C3%A1n+Bringas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E110>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Germ%C3%A1n+Montero/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C0D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Germ%C3%A1n+Vergara/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EDD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerry+Cinnamon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655390>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerry+Rafferty/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gerry+Woo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F160>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gertrudis+Bonilla+y+Jimmy+Puche/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D660>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ger%C3%A4uschkulisse/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CDF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gess/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516B30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gestalt+Girl/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D990>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gesu+No+Kiwami+Otome/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EE90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Get+Karl!+Oh+Soo+Jung+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D2D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Geto+Boys/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437ECB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Getty/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Geumbi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FFA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Geyser/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CEB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gguggugi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DC60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DBA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetonia/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4515120>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Blaster+Ltd./+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E5F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Brothers/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F460>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Flow/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Kids/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Kumb%C3%A9/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655780>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghetto+Starz/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghost/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CAC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ghostface+Killah/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E110>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/GiMGiGaM/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CF40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gia+Huy/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516560>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giacomo+Puccini/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giammateo+Asola/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F7C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gian+Marco/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DD20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giancanna/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F5E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giang+Trang/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46553F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gianluca+Vacchi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CC70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gianluigi+Gelmetti/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gianmarco/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EF50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giant/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D7B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giant+Pink/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B45163B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giant+Rooks/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F130>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giants+Of+Latin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FAC0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giao+Linh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DC90>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gichy+Dan's+Beachwood+No.+9/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DF30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gifuto-Chekku/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655750>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gigante+C%C3%A9sar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C880>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gigi+Rezende/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CF70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gigolo+y+La+Exce/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gigs/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E1A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gil+Gun/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4517340>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gil+L%C3%AA/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DE10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gil+Me+(%EA%B8%B8%EB%AF%B8)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gil+Scott-Heron/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CF70>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/GilMe+%EA%B8%B8%EB%AF%B8/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E1D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilbert+Gill/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655720>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilbert+O'Sullivan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C850>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+Gil/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EBF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+Lazaro+Gaono-Cilindro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D090>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+L%C3%A1zaro+Gaona-Cilindro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C6A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+L%C3%B3pez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4515270>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+Pasillo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FEE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+P%C3%A9rez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E4A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+Santa+Rosa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F040>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+Valenzuela+Con+El+Mariachi+Vargas+De+Tecalitlan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D060>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilberto+y+Su+Sextete/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46557E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilda/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F7F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gildardo+Alvarez/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E5F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gildardo+Montoya+y+Conjunto+Los+Rumberos/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D7B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilgamesh/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DE40>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilgun/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4514640>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gill/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F040>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gillan/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F5E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilles+Peterson's+Havana+Cultura+Band/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437CCD0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gillian+Gordon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gillian+Nguy%E1%BB%85n/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46554B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gillian+Welch/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DBA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gilme+(%EA%B8%B8%EB%AF%B8)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D060>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gimmick./+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FB50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gim%C3%A9nez+L%C3%B3pez+/+Bass+/+Suarez+/+Scampino/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E410>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gin+Blossoms/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516560>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gin+Tuan+Kiet/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C1F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gina/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C6A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gina+G/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C400>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginga+Nagareboshi+Gin/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginga+Nagareboshi+Gin+BGM+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46556C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginger+Baker/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F550>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginibini/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DAB0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginji+Ito/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E5F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginjo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E410>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gino+Emnes/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516560>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gino+Monterrey/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EE30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Ginuwine/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F760>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gionas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D840>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giorgia+Fumanti/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giorgio+Moroder/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655450>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giovanni/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E1A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giovanni+Allevi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F190>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giovanni+Hidalgo/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giovanni+Pacini/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E410>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giovanni+Piacentini/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4515E10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gipsy+Kings/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C310>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gipsy+Latina/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FE50>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gipsyland/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EB30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl+Crush/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FBE0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl+Friends/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655540>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl+Fry/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E050>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl's+Day/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D2D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl's+Day+(%EA%B1%B8%EC%8A%A4%EB%8D%B0%EC%9D%B4)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F8B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl's+World/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girl2School/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B45163B0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FA60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Aloud/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DC60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Dead+Monster+Starring+Lisa/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DD20>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Girls/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E4D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Next+Door/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655540>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Planet+999/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E740>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+Tape+Store/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E080>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls+on+Top/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FAF0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls'+Generation+/+SNSD/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls'+Generation-Oh!GG/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516B30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls'+Generation-TTS/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E5F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girlschool/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D3F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls%E2%80%99+Generation/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F370>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Girls%E2%80%99+Generation+%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EB30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giro/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655690>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gis+Maj+Es+(G.M.E.)/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C7F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gisela+Lavado/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DD80>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gisle+Kverndokk/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E020>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gisselle/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FCA0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gitaroo+Man+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516B30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gitogito+Hustler/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437F700>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giuseppe+Filianoti/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FF10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giuseppe+Mirabella/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DB10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giuseppe+Verdi/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437EB30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Giveon/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4655450>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gjertrud+%C3%98kland/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437DC60>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gjon's+Tears/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E7D0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gladys+Knight/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437FF10>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glam+Grammar/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E5F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glass+Animals/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B4516B30>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glass+Shoes+OST/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C6A0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glass+Tiger/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437E170>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glasvegas/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C820>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gleam/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C7F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gleb/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B46556C0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Gleemen/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437C1F0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))
# Request error: HTTPSConnectionPool(host='www.last.fm', port=443): Max retries exceeded with url: /music/Glen+Campbell/+tracks?date_preset=ALL (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D4B437D7E0>: Failed to resolve 'www.last.fm' ([Errno 11001] getaddrinfo failed)"))

# %% [markdown]
# https://api.socialcounts.org/youtube-video-live-view-count/8xg3vE8Ie_E
