# %%
import os
import pandas as pd

# %%
fileIndex = "18961-25280" 
folder_path = f'../../phase 1/crawl_data/data_{fileIndex}'

csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
merged_data = pd.DataFrame()
for csv_file in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    df = pd.read_csv(file_path)
    merged_data = pd.concat([merged_data, df], ignore_index=True)

# %%
merged_data.to_csv(f'../merge_data/song_data_{fileIndex}.csv', index=False)

# %%
data_frame = pd.read_csv("../merge_data/song_data_25280-31605.csv")
artist_data = pd.read_csv("./artist_data.csv")
# Out:
# C:\Users\minhd\AppData\Local\Temp\ipykernel_18692\2218506772.py:1: DtypeWarning: Columns (0,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv("../merge_data/song_data_25280-31605.csv")

# %%
merged_data_5 = pd.merge(data_frame, artist_data, left_on='artist', right_on='Name', how='inner')
result_data_frame_5 = merged_data_5[data_frame.columns]

# %%
result_data_frame_5
# Out:
#                       title artist   area youtube_link spotify_link  \
# 0               Borrachixxx   xuxo  Latin          NaN          NaN
# 1                 Margarita   xuxo  Latin          NaN          NaN
# 2               Pa’ Mi Casa   xuxo  Latin          NaN          NaN
# 3             Agüita Fresca   xuxo  Latin          NaN          NaN
# 4                 Toxicidad   xuxo  Latin          NaN          NaN
# ...                     ...    ...    ...          ...          ...
# 152481                Unsui    大谷幸     JP          NaN          NaN
# 152482  Rhythm Emotion Pure    大谷幸     JP          NaN          NaN
# 152483      Requiem, Softly    大谷幸     JP          NaN          NaN
# 152484       廃虚の門番 〜巨像との戦い〜    大谷幸     JP          NaN          NaN
# 152485                  お茶会    大谷幸     JP          NaN          NaN
#
#         release_date  youtube_view_count  youtube_like_count  tag  duration  \
# ...

# %%
result_dataframe = pd.concat([merged_data, merged_data_2, merged_data_3, merged_data_4, merged_data_5])

# %%
result_dataframe.to_csv(f'../merge_data/song_data.csv', index=False)

# %%
result_dataframe = result_dataframe.drop(columns=["Spotify_ID", "Spotify_Name", "Similarity_ratio"])

# %%
result_dataframe = result_dataframe.drop(columns = ["Name", "Area"])

# %%
result_dataframe['spotify_link'] = result_dataframe.apply(lambda row: row['spotify_link'].split("/")[-1] if pd.notnull(row['spotify_link']) else row['spotify_link'], axis=1)

# %%
result_dataframe
# Out:
#                                                     title    artist area  \
# 0                                       Stop For A Minute  "#Botsu"   JP
# 1       (darude) sandstorm (original mix)[www homeofmu...  "#Botsu"   JP
# 2                                       20 Titelnummer 20  "#Botsu"   JP
# 3                              The Shirelles - Mamma Said  "#Botsu"   JP
# 4                                                    Thaw  "#Botsu"   JP
# ...                                                   ...       ...  ...
# 152481                                              Unsui       大谷幸   JP
# 152482                                Rhythm Emotion Pure       大谷幸   JP
# 152483                                    Requiem, Softly       大谷幸   JP
# 152484                                     廃虚の門番 〜巨像との戦い〜       大谷幸   JP
# 152485                                                お茶会       大谷幸   JP
#
#                                        youtube_link            spotify_link  \
# ...
